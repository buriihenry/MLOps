# %%
# !python -V
# Out:
# Python 3.10.5

# %%
import pandas as pd

# %%
import pickle
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

from sklearn.metrics import mean_squared_error

# %%
import mlflow

mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("nyc-taxi-experiment")
# Out:
# 2023/04/10 16:28:56 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2023/04/10 16:28:56 INFO mlflow.store.db.utils: Updating database tables
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# <Experiment: artifact_location='file:///d:/henry/Data Science/MLops/experiment-tracking/mlruns/1', creation_time=1680063114319, experiment_id='1', last_update_time=1680063114319, lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>

# %%
df = pd.read_parquet('./data/green_tripdata_2021-01.parquet')

df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

df = df[(df.duration >= 1) & (df.duration <= 60)]

categorical = ['PULocationID', 'DOLocationID']
numerical = ['trip_distance']

df[categorical] = df[categorical].astype(str)

# %%
train_dicts = df[categorical + numerical].to_dict(orient='records')

dv = DictVectorizer()
X_train = dv.fit_transform(train_dicts)

target = 'duration'
y_train = df[target].values

lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_train)

mean_squared_error(y_train, y_pred, squared=False)
# Out:
# 9.838799799829477

# %%
sns.distplot(y_pred, label='prediction')
sns.distplot(y_train, label='actual')

plt.legend()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_16452\1672306066.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_pred, label='prediction')
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_16452\1672306066.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_train, label='actual')

# %%
def read_dataframe(filename):
    if filename.endswith('.csv'):
        df = pd.read_csv(filename)

        df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
        df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
    elif filename.endswith('.parquet'):
        df = pd.read_parquet(filename)

    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ['PULocationID', 'DOLocationID']
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
df_train = read_dataframe('./data/green_tripdata_2021-01.parquet')
df_val = read_dataframe('./data/green_tripdata_2021-02.parquet')

# %%
len(df_train), len(df_val)
# Out:
# (73908, 61921)

# %%
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
categorical = ['PU_DO'] #'PULocationID', 'DOLocationID']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

mean_squared_error(y_val, y_pred, squared=False)
# Out:
# 7.758715204122913

# %%
with open('models/lin_reg.bin', 'wb') as f_out:
    pickle.dump((dv, lr), f_out)

# %%
with mlflow.start_run():

    mlflow.set_tag("Develpoer", "Henry")
    mlflow.log_param("train-data-path", "./data/green_tripdata_2021-01.parquet")
    mlflow.log_param("Val-data-path", "./data/green_tripdata_2021-02.parquet")

    alpha = 0.01

    mlflow.log_param("alpha",alpha)

    lr = Lasso(alpha)
    lr.fit(X_train, y_train)

    y_pred = lr.predict(X_val)

    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)

# %%
import xgboost as xgb

from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)

    return {'loss': rmse, 'status': STATUS_OK}

# %%
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42
}

best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)
# Out:
# [16:29:13] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:14.17961
# [1]	validation-rmse:10.36242
# [2]	validation-rmse:8.42109
# [3]	validation-rmse:7.48639
# [4]	validation-rmse:7.03905
# [5]	validation-rmse:6.81822
# [6]	validation-rmse:6.70017
# [7]	validation-rmse:6.63755
# [8]	validation-rmse:6.60233
# [9]	validation-rmse:6.57560
# [10]	validation-rmse:6.55875
# [11]	validation-rmse:6.55089
# [12]	validation-rmse:6.54424
# [13]	validation-rmse:6.53671
# [14]	validation-rmse:6.53225
# [15]	validation-rmse:6.52861
# [16]	validation-rmse:6.52512
# [17]	validation-rmse:6.52253
# [18]	validation-rmse:6.51798
# [19]	validation-rmse:6.51710
# [20]	validation-rmse:6.51481
# [21]	validation-rmse:6.51233
# [22]	validation-rmse:6.51072
# [23]	validation-rmse:6.51002
# [24]	validation-rmse:6.50814
# [25]	validation-rmse:6.50719
# [26]	validation-rmse:6.50555
# [27]	validation-rmse:6.50510
# [28]	validation-rmse:6.50422
# [29]	validation-rmse:6.50331
# [30]	validation-rmse:6.50251
# [31]	validation-rmse:6.50192
# [32]	validation-rmse:6.50107
# [33]	validation-rmse:6.49848
# [34]	validation-rmse:6.49838
# [35]	validation-rmse:6.49721
# [36]	validation-rmse:6.49661
# [37]	validation-rmse:6.49531
# [38]	validation-rmse:6.49390
# [39]	validation-rmse:6.49210
# [40]	validation-rmse:6.49171
# [41]	validation-rmse:6.48666
# [42]	validation-rmse:6.48649
# [43]	validation-rmse:6.48544
# [44]	validation-rmse:6.48529
# [45]	validation-rmse:6.48355
# [46]	validation-rmse:6.48383
# [47]	validation-rmse:6.48364
# [48]	validation-rmse:6.48320
# [49]	validation-rmse:6.48244
# [50]	validation-rmse:6.48180
# [51]	validation-rmse:6.48045
# [52]	validation-rmse:6.48029
# [53]	validation-rmse:6.48008
# [54]	validation-rmse:6.47877
# [55]	validation-rmse:6.47820
# [56]	validation-rmse:6.47847
# [57]	validation-rmse:6.47812
# [58]	validation-rmse:6.47795
# [59]	validation-rmse:6.47748
# [60]	validation-rmse:6.47768
# [61]	validation-rmse:6.47767
# [62]	validation-rmse:6.47507
# [63]	validation-rmse:6.47523
# [64]	validation-rmse:6.47396
# [65]	validation-rmse:6.47378
# [66]	validation-rmse:6.47413
# [67]	validation-rmse:6.47342
# [68]	validation-rmse:6.47319
# [69]	validation-rmse:6.47263
# [70]	validation-rmse:6.47269
# [71]	validation-rmse:6.47234
# [72]	validation-rmse:6.47146
# [73]	validation-rmse:6.47143
# [74]	validation-rmse:6.47140
# [75]	validation-rmse:6.47118
# [76]	validation-rmse:6.47088
# [77]	validation-rmse:6.47054
# [78]	validation-rmse:6.47071
# [79]	validation-rmse:6.46975
# [80]	validation-rmse:6.46856
# [81]	validation-rmse:6.46838
# [82]	validation-rmse:6.46799
# [83]	validation-rmse:6.46810
# [84]	validation-rmse:6.46896
# [85]	validation-rmse:6.46872
# [86]	validation-rmse:6.46824
# [87]	validation-rmse:6.46792
# [88]	validation-rmse:6.46825
# [89]	validation-rmse:6.46828
# [90]	validation-rmse:6.46850
# [91]	validation-rmse:6.46825
# [92]	validation-rmse:6.46838
# [93]	validation-rmse:6.46913
# [94]	validation-rmse:6.46919
# [95]	validation-rmse:6.46913
# [96]	validation-rmse:6.46901
# [97]	validation-rmse:6.46899
# [98]	validation-rmse:6.46922
# [99]	validation-rmse:6.47018
# [100]	validation-rmse:6.47036
# [101]	validation-rmse:6.47287
# [102]	validation-rmse:6.47336
# [103]	validation-rmse:6.47305
# [104]	validation-rmse:6.47310
# [105]	validation-rmse:6.47283
# [106]	validation-rmse:6.47296
# [107]	validation-rmse:6.47276
# [108]	validation-rmse:6.47298
# [109]	validation-rmse:6.47295
# [110]	validation-rmse:6.47294
# [111]	validation-rmse:6.47271
# [112]	validation-rmse:6.47261
# [113]	validation-rmse:6.47240
# [114]	validation-rmse:6.47208
# [115]	validation-rmse:6.47217
# [116]	validation-rmse:6.47247
# [117]	validation-rmse:6.47222
# [118]	validation-rmse:6.47203
# [119]	validation-rmse:6.47203
# [120]	validation-rmse:6.47211
# [121]	validation-rmse:6.47234
# [122]	validation-rmse:6.47237
# [123]	validation-rmse:6.47247
# [124]	validation-rmse:6.47242
# [125]	validation-rmse:6.47266
# [126]	validation-rmse:6.47292
# [127]	validation-rmse:6.47285
# [128]	validation-rmse:6.47288
# [129]	validation-rmse:6.47257
# [130]	validation-rmse:6.47270
# [131]	validation-rmse:6.47365
# [132]	validation-rmse:6.47417
# [133]	validation-rmse:6.47408
# [134]	validation-rmse:6.47421
# [135]	validation-rmse:6.47381
# [136]	validation-rmse:6.47364
# [137]	validation-rmse:6.47354
# [16:29:27] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:17.19158
# [1]	validation-rmse:14.20547
# [2]	validation-rmse:12.00687
# [3]	validation-rmse:10.41733
# [4]	validation-rmse:9.28469
# [5]	validation-rmse:8.49161
# [6]	validation-rmse:7.94290
# [7]	validation-rmse:7.56655
# [8]	validation-rmse:7.30869
# [9]	validation-rmse:7.12970
# [10]	validation-rmse:7.00220
# [11]	validation-rmse:6.91157
# [12]	validation-rmse:6.84684
# [13]	validation-rmse:6.79968
# [14]	validation-rmse:6.76435
# [15]	validation-rmse:6.73789
# [16]	validation-rmse:6.71756
# [17]	validation-rmse:6.70184
# [18]	validation-rmse:6.69026
# [19]	validation-rmse:6.68046
# [20]	validation-rmse:6.67326
# [21]	validation-rmse:6.66755
# [22]	validation-rmse:6.66356
# [23]	validation-rmse:6.66000
# [24]	validation-rmse:6.65670
# [25]	validation-rmse:6.65444
# [26]	validation-rmse:6.65185
# [27]	validation-rmse:6.64998
# [28]	validation-rmse:6.64810
# [29]	validation-rmse:6.64657
# [30]	validation-rmse:6.64541
# [31]	validation-rmse:6.64454
# [32]	validation-rmse:6.64342
# [33]	validation-rmse:6.64279
# [34]	validation-rmse:6.64135
# [35]	validation-rmse:6.63963
# [36]	validation-rmse:6.63894
# [37]	validation-rmse:6.63838
# [38]	validation-rmse:6.63755
# [39]	validation-rmse:6.63678
# [40]	validation-rmse:6.63634
# [41]	validation-rmse:6.63574
# [42]	validation-rmse:6.63491
# [43]	validation-rmse:6.63408
# [44]	validation-rmse:6.63332
# [45]	validation-rmse:6.63292
# [46]	validation-rmse:6.63251
# [47]	validation-rmse:6.63171
# [48]	validation-rmse:6.63126
# [49]	validation-rmse:6.63077
# [50]	validation-rmse:6.63019
# [51]	validation-rmse:6.62941
# [52]	validation-rmse:6.62897
# [53]	validation-rmse:6.62854
# [54]	validation-rmse:6.62704
# [55]	validation-rmse:6.62617
# [56]	validation-rmse:6.62601
# [57]	validation-rmse:6.62580
# [58]	validation-rmse:6.62534
# [59]	validation-rmse:6.62517
# [60]	validation-rmse:6.62495
# [61]	validation-rmse:6.62283
# [62]	validation-rmse:6.62232
# [63]	validation-rmse:6.62114
# [64]	validation-rmse:6.62083
# [65]	validation-rmse:6.62015
# [66]	validation-rmse:6.61995
# [67]	validation-rmse:6.61968
# [68]	validation-rmse:6.61959
# [69]	validation-rmse:6.61942
# [70]	validation-rmse:6.61899
# [71]	validation-rmse:6.61876
# [72]	validation-rmse:6.61858
# [73]	validation-rmse:6.61835
# [74]	validation-rmse:6.61791
# [75]	validation-rmse:6.61759
# [76]	validation-rmse:6.61727
# [77]	validation-rmse:6.61677
# [78]	validation-rmse:6.61659
# [79]	validation-rmse:6.61673
# [80]	validation-rmse:6.61655
# [81]	validation-rmse:6.61643
# [82]	validation-rmse:6.61608
# [83]	validation-rmse:6.61577
# [84]	validation-rmse:6.61540
# [85]	validation-rmse:6.61516
# [86]	validation-rmse:6.61400
# [87]	validation-rmse:6.61351
# [88]	validation-rmse:6.61264
# [89]	validation-rmse:6.61239
# [90]	validation-rmse:6.61173
# [91]	validation-rmse:6.61168
# [92]	validation-rmse:6.61108
# [93]	validation-rmse:6.61107
# [94]	validation-rmse:6.61083
# [95]	validation-rmse:6.61053
# [96]	validation-rmse:6.61022
# [97]	validation-rmse:6.61000
# [98]	validation-rmse:6.60974
# [99]	validation-rmse:6.60932
# [100]	validation-rmse:6.60895
# [101]	validation-rmse:6.60858
# [102]	validation-rmse:6.60802
# [103]	validation-rmse:6.60745
# [104]	validation-rmse:6.60721
# [105]	validation-rmse:6.60686
# [106]	validation-rmse:6.60647
# [107]	validation-rmse:6.60623
# [108]	validation-rmse:6.60534
# [109]	validation-rmse:6.60508
# [110]	validation-rmse:6.60498
# [111]	validation-rmse:6.60477
# [112]	validation-rmse:6.60487
# [113]	validation-rmse:6.60473
# [114]	validation-rmse:6.60456
# [115]	validation-rmse:6.60424
# [116]	validation-rmse:6.60374
# [117]	validation-rmse:6.60362
# [118]	validation-rmse:6.60357
# [119]	validation-rmse:6.60348
# [120]	validation-rmse:6.60321
# [121]	validation-rmse:6.60315
# [122]	validation-rmse:6.60298
# [123]	validation-rmse:6.60284
# [124]	validation-rmse:6.60256
# [125]	validation-rmse:6.60240
# [126]	validation-rmse:6.60245
# [127]	validation-rmse:6.60222
# [128]	validation-rmse:6.60203
# [129]	validation-rmse:6.60171
# [130]	validation-rmse:6.60158
# [131]	validation-rmse:6.60163
# [132]	validation-rmse:6.60133
# [133]	validation-rmse:6.60094
# [134]	validation-rmse:6.60063
# [135]	validation-rmse:6.60038
# [136]	validation-rmse:6.60028
# [137]	validation-rmse:6.60027
# [138]	validation-rmse:6.60002
# [139]	validation-rmse:6.60003
# [140]	validation-rmse:6.59992
# [141]	validation-rmse:6.59990
# [142]	validation-rmse:6.59967
# [143]	validation-rmse:6.59916
# [144]	validation-rmse:6.59929
# [145]	validation-rmse:6.59911
# [146]	validation-rmse:6.59913
# [147]	validation-rmse:6.59882
# [148]	validation-rmse:6.59873
# [149]	validation-rmse:6.59857
# [150]	validation-rmse:6.59834
# [151]	validation-rmse:6.59787
# [152]	validation-rmse:6.59797
# [153]	validation-rmse:6.59794
# [154]	validation-rmse:6.59787
# [155]	validation-rmse:6.59789
# [156]	validation-rmse:6.59774
# [157]	validation-rmse:6.59770
# [158]	validation-rmse:6.59762
# [159]	validation-rmse:6.59754
# [160]	validation-rmse:6.59751
# [161]	validation-rmse:6.59744
# [162]	validation-rmse:6.59738
# [163]	validation-rmse:6.59721
# [164]	validation-rmse:6.59738
# [165]	validation-rmse:6.59740
# [166]	validation-rmse:6.59727
# [167]	validation-rmse:6.59715
# [168]	validation-rmse:6.59702
# [169]	validation-rmse:6.59683
# [170]	validation-rmse:6.59671
# [171]	validation-rmse:6.59651
# [172]	validation-rmse:6.59655
# [173]	validation-rmse:6.59687
# [174]	validation-rmse:6.59693
# [175]	validation-rmse:6.59687
# [176]	validation-rmse:6.59686
# [177]	validation-rmse:6.59655
# [178]	validation-rmse:6.59642
# [179]	validation-rmse:6.59630
# [180]	validation-rmse:6.59628
# [181]	validation-rmse:6.59610
# [182]	validation-rmse:6.59598
# [183]	validation-rmse:6.59578
# [184]	validation-rmse:6.59565
# [185]	validation-rmse:6.59569
# [186]	validation-rmse:6.59562
# [187]	validation-rmse:6.59563
# [188]	validation-rmse:6.59566
# [189]	validation-rmse:6.59560
# [190]	validation-rmse:6.59555
# [191]	validation-rmse:6.59546
# [192]	validation-rmse:6.59544
# [193]	validation-rmse:6.59532
# [194]	validation-rmse:6.59517
# [195]	validation-rmse:6.59489
# [196]	validation-rmse:6.59484
# [197]	validation-rmse:6.59477
# [198]	validation-rmse:6.59463
# [199]	validation-rmse:6.59458
# [200]	validation-rmse:6.59461
# [201]	validation-rmse:6.59417
# [202]	validation-rmse:6.59406
# [203]	validation-rmse:6.59390
# [204]	validation-rmse:6.59389
# [205]	validation-rmse:6.59383
# [206]	validation-rmse:6.59377
# [207]	validation-rmse:6.59365
# [208]	validation-rmse:6.59352
# [209]	validation-rmse:6.59339
# [210]	validation-rmse:6.59324
# [211]	validation-rmse:6.59299
# [212]	validation-rmse:6.59321
# [213]	validation-rmse:6.59310
# [214]	validation-rmse:6.59304
# [215]	validation-rmse:6.59282
# [216]	validation-rmse:6.59267
# [217]	validation-rmse:6.59275
# [218]	validation-rmse:6.59262
# [219]	validation-rmse:6.59243
# [220]	validation-rmse:6.59233
# [221]	validation-rmse:6.59218
# [222]	validation-rmse:6.59214
# [223]	validation-rmse:6.59207
# [224]	validation-rmse:6.59191
# [225]	validation-rmse:6.59192
# [226]	validation-rmse:6.59197
# [227]	validation-rmse:6.59230
# [228]	validation-rmse:6.59202
# [229]	validation-rmse:6.59199
# [230]	validation-rmse:6.59184
# [231]	validation-rmse:6.59168
# [232]	validation-rmse:6.59153
# [233]	validation-rmse:6.59142
# [234]	validation-rmse:6.59133
# [235]	validation-rmse:6.59136
# [236]	validation-rmse:6.59121
# [237]	validation-rmse:6.59117
# [238]	validation-rmse:6.59099
# [239]	validation-rmse:6.59081
# [240]	validation-rmse:6.59081
# [241]	validation-rmse:6.59079
# [242]	validation-rmse:6.59083
# [243]	validation-rmse:6.59094
# [244]	validation-rmse:6.59100
# [245]	validation-rmse:6.59106
# [246]	validation-rmse:6.59102
# [247]	validation-rmse:6.59096
# [248]	validation-rmse:6.59073
# [249]	validation-rmse:6.59090
# [250]	validation-rmse:6.59084
# [251]	validation-rmse:6.59070
# [252]	validation-rmse:6.59060
# [253]	validation-rmse:6.59045
# [254]	validation-rmse:6.59033
# [255]	validation-rmse:6.59034
# [256]	validation-rmse:6.59029
# [257]	validation-rmse:6.59026
# [258]	validation-rmse:6.59043
# [259]	validation-rmse:6.59061
# [260]	validation-rmse:6.59040
# [261]	validation-rmse:6.59024
# [262]	validation-rmse:6.59003
# [263]	validation-rmse:6.59010
# [264]	validation-rmse:6.59006
# [265]	validation-rmse:6.59002
# [266]	validation-rmse:6.58991
# [267]	validation-rmse:6.58990
# [268]	validation-rmse:6.58983
# [269]	validation-rmse:6.58976
# [270]	validation-rmse:6.58954
# [271]	validation-rmse:6.58949
# [272]	validation-rmse:6.58910
# [273]	validation-rmse:6.58909
# [274]	validation-rmse:6.58947
# [275]	validation-rmse:6.58924
# [276]	validation-rmse:6.58924
# [277]	validation-rmse:6.58913
# [278]	validation-rmse:6.58926
# [279]	validation-rmse:6.58907
# [280]	validation-rmse:6.58905
# [281]	validation-rmse:6.58899
# [282]	validation-rmse:6.58904
# [283]	validation-rmse:6.58899
# [284]	validation-rmse:6.58882
# [285]	validation-rmse:6.58882
# [286]	validation-rmse:6.58881
# [287]	validation-rmse:6.58872
# [288]	validation-rmse:6.58849
# [289]	validation-rmse:6.58856
# [290]	validation-rmse:6.58855
# [291]	validation-rmse:6.58832
# [292]	validation-rmse:6.58849
# [293]	validation-rmse:6.58853
# [294]	validation-rmse:6.58840
# [295]	validation-rmse:6.58838
# [296]	validation-rmse:6.58831
# [297]	validation-rmse:6.58825
# [298]	validation-rmse:6.58820
# [299]	validation-rmse:6.58797
# [300]	validation-rmse:6.58779
# [301]	validation-rmse:6.58759
# [302]	validation-rmse:6.58783
# [303]	validation-rmse:6.58786
# [304]	validation-rmse:6.58777
# [305]	validation-rmse:6.58765
# [306]	validation-rmse:6.58754
# [307]	validation-rmse:6.58756
# [308]	validation-rmse:6.58731
# [309]	validation-rmse:6.58724
# [310]	validation-rmse:6.58720
# [311]	validation-rmse:6.58712
# [312]	validation-rmse:6.58707
# [313]	validation-rmse:6.58699
# [314]	validation-rmse:6.58697
# [315]	validation-rmse:6.58706
# [316]	validation-rmse:6.58702
# [317]	validation-rmse:6.58671
# [318]	validation-rmse:6.58672
# [319]	validation-rmse:6.58651
# [320]	validation-rmse:6.58648
# [321]	validation-rmse:6.58679
# [322]	validation-rmse:6.58669
# [323]	validation-rmse:6.58668
# [324]	validation-rmse:6.58669
# [325]	validation-rmse:6.58710
# [326]	validation-rmse:6.58707
# [327]	validation-rmse:6.58700
# [328]	validation-rmse:6.58683
# [329]	validation-rmse:6.58681
# [330]	validation-rmse:6.58682
# [331]	validation-rmse:6.58686
# [332]	validation-rmse:6.58674
# [333]	validation-rmse:6.58667
# [334]	validation-rmse:6.58654
# [335]	validation-rmse:6.58676
# [336]	validation-rmse:6.58648
# [337]	validation-rmse:6.58651
# [338]	validation-rmse:6.58660
# [339]	validation-rmse:6.58644
# [340]	validation-rmse:6.58638
# [341]	validation-rmse:6.58628
# [342]	validation-rmse:6.58598
# [343]	validation-rmse:6.58603
# [344]	validation-rmse:6.58619
# [345]	validation-rmse:6.58618
# [346]	validation-rmse:6.58615
# [347]	validation-rmse:6.58619
# [348]	validation-rmse:6.58602
# [349]	validation-rmse:6.58604
# [350]	validation-rmse:6.58615
# [351]	validation-rmse:6.58597
# [352]	validation-rmse:6.58598
# [353]	validation-rmse:6.58598
# [354]	validation-rmse:6.58601
# [355]	validation-rmse:6.58580
# [356]	validation-rmse:6.58578
# [357]	validation-rmse:6.58579
# [358]	validation-rmse:6.58572
# [359]	validation-rmse:6.58561
# [360]	validation-rmse:6.58545
# [361]	validation-rmse:6.58551
# [362]	validation-rmse:6.58557
# [363]	validation-rmse:6.58560
# [364]	validation-rmse:6.58563
# [365]	validation-rmse:6.58551
# [366]	validation-rmse:6.58554
# [367]	validation-rmse:6.58545
# [368]	validation-rmse:6.58543
# [369]	validation-rmse:6.58550
# [370]	validation-rmse:6.58558
# [371]	validation-rmse:6.58532
# [372]	validation-rmse:6.58527
# [373]	validation-rmse:6.58526
# [374]	validation-rmse:6.58532
# [375]	validation-rmse:6.58538
# [376]	validation-rmse:6.58547
# [377]	validation-rmse:6.58550
# [378]	validation-rmse:6.58548
# [379]	validation-rmse:6.58544
# [380]	validation-rmse:6.58542
# [381]	validation-rmse:6.58539
# [382]	validation-rmse:6.58528
# [383]	validation-rmse:6.58528
# [384]	validation-rmse:6.58534
# [385]	validation-rmse:6.58564
# [386]	validation-rmse:6.58551
# [387]	validation-rmse:6.58544
# [388]	validation-rmse:6.58517
# [389]	validation-rmse:6.58526
# [390]	validation-rmse:6.58531
# [391]	validation-rmse:6.58527
# [392]	validation-rmse:6.58528
# [393]	validation-rmse:6.58524
# [394]	validation-rmse:6.58516
# [395]	validation-rmse:6.58513
# [396]	validation-rmse:6.58501
# [397]	validation-rmse:6.58496
# [398]	validation-rmse:6.58491
# [399]	validation-rmse:6.58479
# [400]	validation-rmse:6.58481
# [401]	validation-rmse:6.58481
# [402]	validation-rmse:6.58485
# [403]	validation-rmse:6.58482
# [404]	validation-rmse:6.58479
# [405]	validation-rmse:6.58478
# [406]	validation-rmse:6.58471
# [407]	validation-rmse:6.58470
# [408]	validation-rmse:6.58459
# [409]	validation-rmse:6.58471
# [410]	validation-rmse:6.58480
# [411]	validation-rmse:6.58475
# [412]	validation-rmse:6.58484
# [413]	validation-rmse:6.58491
# [414]	validation-rmse:6.58498
# [415]	validation-rmse:6.58489
# [416]	validation-rmse:6.58485
# [417]	validation-rmse:6.58477
# [418]	validation-rmse:6.58474
# [419]	validation-rmse:6.58475
# [420]	validation-rmse:6.58480
# [421]	validation-rmse:6.58473
# [422]	validation-rmse:6.58474
# [423]	validation-rmse:6.58478
# [424]	validation-rmse:6.58479
# [425]	validation-rmse:6.58471
# [426]	validation-rmse:6.58467
# [427]	validation-rmse:6.58463
# [428]	validation-rmse:6.58463
# [429]	validation-rmse:6.58476
# [430]	validation-rmse:6.58486
# [431]	validation-rmse:6.58474
# [432]	validation-rmse:6.58482
# [433]	validation-rmse:6.58485
# [434]	validation-rmse:6.58481
# [435]	validation-rmse:6.58475
# [436]	validation-rmse:6.58474
# [437]	validation-rmse:6.58473
# [438]	validation-rmse:6.58466
# [439]	validation-rmse:6.58465
# [440]	validation-rmse:6.58462
# [441]	validation-rmse:6.58460
# [442]	validation-rmse:6.58449
# [443]	validation-rmse:6.58461
# [444]	validation-rmse:6.58468
# [445]	validation-rmse:6.58453
# [446]	validation-rmse:6.58466
# [447]	validation-rmse:6.58465
# [448]	validation-rmse:6.58472
# [449]	validation-rmse:6.58475
# [450]	validation-rmse:6.58461
# [451]	validation-rmse:6.58472
# [452]	validation-rmse:6.58465
# [453]	validation-rmse:6.58463
# [454]	validation-rmse:6.58458
# [455]	validation-rmse:6.58459
# [456]	validation-rmse:6.58458
# [457]	validation-rmse:6.58458
# [458]	validation-rmse:6.58452
# [459]	validation-rmse:6.58434
# [460]	validation-rmse:6.58433
# [461]	validation-rmse:6.58437
# [462]	validation-rmse:6.58435
# [463]	validation-rmse:6.58447
# [464]	validation-rmse:6.58455
# [465]	validation-rmse:6.58449
# [466]	validation-rmse:6.58444
# [467]	validation-rmse:6.58445
# [468]	validation-rmse:6.58444
# [469]	validation-rmse:6.58436
# [470]	validation-rmse:6.58436
# [471]	validation-rmse:6.58431
# [472]	validation-rmse:6.58416
# [473]	validation-rmse:6.58407
# [474]	validation-rmse:6.58389
# [475]	validation-rmse:6.58386
# [476]	validation-rmse:6.58377
# [477]	validation-rmse:6.58373
# [478]	validation-rmse:6.58370
# [479]	validation-rmse:6.58368
# [480]	validation-rmse:6.58372
# [481]	validation-rmse:6.58351
# [482]	validation-rmse:6.58344
# [483]	validation-rmse:6.58345
# [484]	validation-rmse:6.58337
# [485]	validation-rmse:6.58351
# [486]	validation-rmse:6.58337
# [487]	validation-rmse:6.58344
# [488]	validation-rmse:6.58340
# [489]	validation-rmse:6.58337
# [490]	validation-rmse:6.58333
# [491]	validation-rmse:6.58338
# [492]	validation-rmse:6.58333
# [493]	validation-rmse:6.58325
# [494]	validation-rmse:6.58323
# [495]	validation-rmse:6.58317
# [496]	validation-rmse:6.58309
# [497]	validation-rmse:6.58299
# [498]	validation-rmse:6.58291
# ...
# [137]	validation-rmse:6.43720
# [138]	validation-rmse:6.43760
# [139]	validation-rmse:6.43811
# [140]	validation-rmse:6.43838
# [141]	validation-rmse:6.43832
# [142]	validation-rmse:6.43842
# [143]	validation-rmse:6.43842
# [144]	validation-rmse:6.43880
# [145]	validation-rmse:6.43831
# [146]	validation-rmse:6.43796
# [147]	validation-rmse:6.44015
# [148]	validation-rmse:6.44058
# [149]	validation-rmse:6.44078
# [16:31:17] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:17.18304
# [1]	validation-rmse:14.18542
# [2]	validation-rmse:11.97428
# [3]	validation-rmse:10.36984
# [4]	validation-rmse:9.22705
# [5]	validation-rmse:8.42834
# [6]	validation-rmse:7.87556
# [7]	validation-rmse:7.49344
# [8]	validation-rmse:7.23144
# [9]	validation-rmse:7.05051
# [10]	validation-rmse:6.92334
# [11]	validation-rmse:6.83249
# [12]	validation-rmse:6.76560
# [13]	validation-rmse:6.71946
# [14]	validation-rmse:6.68360
# [15]	validation-rmse:6.65499
# [16]	validation-rmse:6.63311
# [17]	validation-rmse:6.61582
# [18]	validation-rmse:6.60434
# [19]	validation-rmse:6.59301
# [20]	validation-rmse:6.58475
# [21]	validation-rmse:6.57785
# [22]	validation-rmse:6.57428
# [23]	validation-rmse:6.56940
# [24]	validation-rmse:6.56554
# [25]	validation-rmse:6.56319
# [26]	validation-rmse:6.56083
# [27]	validation-rmse:6.55852
# [28]	validation-rmse:6.55674
# [29]	validation-rmse:6.55440
# [30]	validation-rmse:6.55324
# [31]	validation-rmse:6.55218
# [32]	validation-rmse:6.55092
# [33]	validation-rmse:6.54971
# [34]	validation-rmse:6.54848
# [35]	validation-rmse:6.54748
# [36]	validation-rmse:6.54662
# [37]	validation-rmse:6.54498
# [38]	validation-rmse:6.54447
# [39]	validation-rmse:6.54343
# [40]	validation-rmse:6.54217
# [41]	validation-rmse:6.54137
# [42]	validation-rmse:6.54068
# [43]	validation-rmse:6.53984
# [44]	validation-rmse:6.53979
# [45]	validation-rmse:6.53971
# [46]	validation-rmse:6.53911
# [47]	validation-rmse:6.53857
# [48]	validation-rmse:6.53766
# [49]	validation-rmse:6.53692
# [50]	validation-rmse:6.53646
# [51]	validation-rmse:6.53600
# [52]	validation-rmse:6.53550
# [53]	validation-rmse:6.53496
# [54]	validation-rmse:6.53444
#   8%|▊         | 4/50 [02:11<25:09, 32.81s/trial, best loss: 6.44077542841002]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\henry\Data Science\MLops\experiment-tracking\duration-prediction.ipynb Cell 21 in <cell line: 11>()
#       <a href='vscode-notebook-cell:/d%3A/henry/Data%20Science/MLops/experiment-tracking/duration-prediction.ipynb#X26sZmlsZQ%3D%3D?line=0'>1</a> search_space = {
#       <a href='vscode-notebook-cell:/d%3A/henry/Data%20Science/MLops/experiment-tracking/duration-prediction.ipynb#X26sZmlsZQ%3D%3D?line=1'>2</a>     'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
#       <a href='vscode-notebook-cell:/d%3A/henry/Data%20Science/MLops/experiment-tracking/duration-prediction.ipynb#X26sZmlsZQ%3D%3D?line=2'>3</a>     'learning_rate': hp.loguniform('learning_rate', -3, 0),
#    (...)
#       <a href='vscode-notebook-cell:/d%3A/henry/Data%20Science/MLops/experiment-tracking/duration-prediction.ipynb#X26sZmlsZQ%3D%3D?line=7'>8</a>     'seed': 42
#       <a href='vscode-notebook-cell:/d%3A/henry/Data%20Science/MLops/experiment-tracking/duration-prediction.ipynb#X26sZmlsZQ%3D%3D?line=8'>9</a> }
# ---> <a href='vscode-notebook-cell:/d%3A/henry/Data%20Science/MLops/experiment-tracking/duration-prediction.ipynb#X26sZmlsZQ%3D%3D?line=10'>11</a> best_result = fmin(
#      <a href='vscode-notebook-cell:/d%3A/henry/Data%20Science/MLops/experiment-tracking/duration-prediction.ipynb#X26sZmlsZQ%3D%3D?line=11'>12</a>     fn=objective,
#      <a href='vscode-notebook-cell:/d%3A/henry/Data%20Science/MLops/experiment-tracking/duration-prediction.ipynb#X26sZmlsZQ%3D%3D?line=12'>13</a>     space=search_space,
#      <a href='vscode-notebook-cell:/d%3A/henry/Data%20Science/MLops/experiment-tracking/duration-prediction.ipynb#X26sZmlsZQ%3D%3D?line=13'>14</a>     algo=tpe.suggest,
#      <a href='vscode-notebook-cell:/d%3A/henry/Data%20Science/MLops/experiment-tracking/duration-prediction.ipynb#X26sZmlsZQ%3D%3D?line=14'>15</a>     max_evals=50,
#      <a href='vscode-notebook-cell:/d%3A/henry/Data%20Science/MLops/experiment-tracking/duration-prediction.ipynb#X26sZmlsZQ%3D%3D?line=15'>16</a>     trials=Trials()
#      <a href='vscode-notebook-cell:/d%3A/henry/Data%20Science/MLops/experiment-tracking/duration-prediction.ipynb#X26sZmlsZQ%3D%3D?line=16'>17</a> )
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\hyperopt\fmin.py:540, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     537     fn = __objective_fmin_wrapper(fn)
#     539 if allow_trials_fmin and hasattr(trials, "fmin"):
# --> 540     return trials.fmin(
#     541         fn,
#     542         space,
#     543         algo=algo,
#     544         max_evals=max_evals,
#     545         timeout=timeout,
#     546         loss_threshold=loss_threshold,
#     547         max_queue_len=max_queue_len,
#     548         rstate=rstate,
#     549         pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     550         verbose=verbose,
#     551         catch_eval_exceptions=catch_eval_exceptions,
#     552         return_argmin=return_argmin,
#     553         show_progressbar=show_progressbar,
#     554         early_stop_fn=early_stop_fn,
#     555         trials_save_file=trials_save_file,
#     556     )
#     558 if trials is None:
#     559     if os.path.exists(trials_save_file):
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\hyperopt\base.py:671, in Trials.fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar, early_stop_fn, trials_save_file)
#     666 # -- Stop-gap implementation!
#     667 #    fmin should have been a Trials method in the first place
#     668 #    but for now it's still sitting in another file.
#     669 from .fmin import fmin
# --> 671 return fmin(
#     672     fn,
#     673     space,
#     674     algo=algo,
#     675     max_evals=max_evals,
#     676     timeout=timeout,
#     677     loss_threshold=loss_threshold,
#     678     trials=self,
#     679     rstate=rstate,
#     680     verbose=verbose,
#     681     max_queue_len=max_queue_len,
#     682     allow_trials_fmin=False,  # -- prevent recursion
#     683     pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     684     catch_eval_exceptions=catch_eval_exceptions,
#     685     return_argmin=return_argmin,
#     686     show_progressbar=show_progressbar,
#     687     early_stop_fn=early_stop_fn,
#     688     trials_save_file=trials_save_file,
#     689 )
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\hyperopt\fmin.py:586, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     583 rval.catch_eval_exceptions = catch_eval_exceptions
#     585 # next line is where the fmin is actually executed
# --> 586 rval.exhaust()
#     588 if return_argmin:
#     589     if len(trials.trials) == 0:
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\hyperopt\fmin.py:364, in FMinIter.exhaust(self)
#     362 def exhaust(self):
#     363     n_done = len(self.trials)
# --> 364     self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     365     self.trials.refresh()
#     366     return self
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\hyperopt\fmin.py:300, in FMinIter.run(self, N, block_until_done)
#     297     time.sleep(self.poll_interval_secs)
#     298 else:
#     299     # -- loop over trials and do the jobs directly
# --> 300     self.serial_evaluate()
#     302 self.trials.refresh()
#     303 if self.trials_save_file != "":
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\hyperopt\fmin.py:178, in FMinIter.serial_evaluate(self, N)
#     176 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     177 try:
# --> 178     result = self.domain.evaluate(spec, ctrl)
#     179 except Exception as e:
#     180     logger.error("job exception: %s" % str(e))
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\hyperopt\base.py:892, in Domain.evaluate(self, config, ctrl, attach_attachments)
#     883 else:
#     884     # -- the "work" of evaluating `config` can be written
#     885     #    either into the pyll part (self.expr)
#     886     #    or the normal Python part (self.fn)
#     887     pyll_rval = pyll.rec_eval(
#     888         self.expr,
#     889         memo=memo,
#     890         print_node_on_error=self.rec_eval_print_node_on_error,
#     891     )
# --> 892     rval = self.fn(pyll_rval)
#     894 if isinstance(rval, (float, int, np.number)):
#     895     dict_rval = {"loss": float(rval), "status": STATUS_OK}
#
# d:\henry\Data Science\MLops\experiment-tracking\duration-prediction.ipynb Cell 21 in objective(params)
#       <a href='vscode-notebook-cell:/d%3A/henry/Data%20Science/MLops/experiment-tracking/duration-prediction.ipynb#X26sZmlsZQ%3D%3D?line=2'>3</a> mlflow.set_tag("model", "xgboost")
#       <a href='vscode-notebook-cell:/d%3A/henry/Data%20Science/MLops/experiment-tracking/duration-prediction.ipynb#X26sZmlsZQ%3D%3D?line=3'>4</a> mlflow.log_params(params)
# ----> <a href='vscode-notebook-cell:/d%3A/henry/Data%20Science/MLops/experiment-tracking/duration-prediction.ipynb#X26sZmlsZQ%3D%3D?line=4'>5</a> booster = xgb.train(
#       <a href='vscode-notebook-cell:/d%3A/henry/Data%20Science/MLops/experiment-tracking/duration-prediction.ipynb#X26sZmlsZQ%3D%3D?line=5'>6</a>     params=params,
#       <a href='vscode-notebook-cell:/d%3A/henry/Data%20Science/MLops/experiment-tracking/duration-prediction.ipynb#X26sZmlsZQ%3D%3D?line=6'>7</a>     dtrain=train,
#       <a href='vscode-notebook-cell:/d%3A/henry/Data%20Science/MLops/experiment-tracking/duration-prediction.ipynb#X26sZmlsZQ%3D%3D?line=7'>8</a>     num_boost_round=1000,
#       <a href='vscode-notebook-cell:/d%3A/henry/Data%20Science/MLops/experiment-tracking/duration-prediction.ipynb#X26sZmlsZQ%3D%3D?line=8'>9</a>     evals=[(valid, 'validation')],
#      <a href='vscode-notebook-cell:/d%3A/henry/Data%20Science/MLops/experiment-tracking/duration-prediction.ipynb#X26sZmlsZQ%3D%3D?line=9'>10</a>     early_stopping_rounds=50
#      <a href='vscode-notebook-cell:/d%3A/henry/Data%20Science/MLops/experiment-tracking/duration-prediction.ipynb#X26sZmlsZQ%3D%3D?line=10'>11</a> )
#      <a href='vscode-notebook-cell:/d%3A/henry/Data%20Science/MLops/experiment-tracking/duration-prediction.ipynb#X26sZmlsZQ%3D%3D?line=11'>12</a> y_pred = booster.predict(valid)
#      <a href='vscode-notebook-cell:/d%3A/henry/Data%20Science/MLops/experiment-tracking/duration-prediction.ipynb#X26sZmlsZQ%3D%3D?line=12'>13</a> rmse = mean_squared_error(y_val, y_pred, squared=False)
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\training.py:185, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     183 if cb_container.before_iteration(bst, i, dtrain, evals):
#     184     break
# --> 185 bst.update(dtrain, i, obj)
#     186 if cb_container.after_iteration(bst, i, dtrain, evals):
#     187     break
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py:1918, in Booster.update(self, dtrain, iteration, fobj)
#    1915 self._validate_dmatrix_features(dtrain)
#    1917 if fobj is None:
# -> 1918     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1919                                             ctypes.c_int(iteration),
#    1920                                             dtrain.handle))
#    1921 else:
#    1922     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %%
mlflow.xgboost.autolog(disable=True)

# %%
params = {
    'learning_rate':	0.14085947015837913,
    'max_depth':	18,
    'min_child_weight':	5.077192878894153,
    'objective':	'reg:linear',
    'reg_alpha':	0.024590862570484703,
    'reg_lambda':	0.00344666697262476,
    'seed':	42


}

mlflow.xgboost.autolog()

booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
)
# Out:
# 2023/04/10 17:05:03 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '7a912515768f48ac8ec14a1e2e6450eb', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# [17:05:03] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:18.68895
# [1]	validation-rmse:16.57661
# [2]	validation-rmse:14.79756
# [3]	validation-rmse:13.30913
# [4]	validation-rmse:12.07001
# [5]	validation-rmse:11.04496
# [6]	validation-rmse:10.20184
# [7]	validation-rmse:9.51249
# [8]	validation-rmse:8.95195
# [9]	validation-rmse:8.49847
# [10]	validation-rmse:8.13295
# [11]	validation-rmse:7.84028
# [12]	validation-rmse:7.60469
# [13]	validation-rmse:7.41619
# [14]	validation-rmse:7.26414
# [15]	validation-rmse:7.14127
# [16]	validation-rmse:7.04214
# [17]	validation-rmse:6.96196
# [18]	validation-rmse:6.89746
# [19]	validation-rmse:6.84417
# [20]	validation-rmse:6.79939
# [21]	validation-rmse:6.76290
# [22]	validation-rmse:6.73331
# [23]	validation-rmse:6.70747
# [24]	validation-rmse:6.68638
# [25]	validation-rmse:6.66771
# [26]	validation-rmse:6.65218
# [27]	validation-rmse:6.64063
# [28]	validation-rmse:6.62959
# [29]	validation-rmse:6.61977
# [30]	validation-rmse:6.61171
# [31]	validation-rmse:6.60531
# [32]	validation-rmse:6.59778
# [33]	validation-rmse:6.59291
# [34]	validation-rmse:6.58947
# [35]	validation-rmse:6.58441
# [36]	validation-rmse:6.58137
# [37]	validation-rmse:6.57854
# [38]	validation-rmse:6.57548
# [39]	validation-rmse:6.57325
# [40]	validation-rmse:6.57067
# [41]	validation-rmse:6.56891
# [42]	validation-rmse:6.56634
# [43]	validation-rmse:6.56502
# [44]	validation-rmse:6.56360
# [45]	validation-rmse:6.56199
# [46]	validation-rmse:6.55987
# [47]	validation-rmse:6.55881
# [48]	validation-rmse:6.55760
# [49]	validation-rmse:6.55610
# [50]	validation-rmse:6.55492
# [51]	validation-rmse:6.55384
# [52]	validation-rmse:6.55200
# [53]	validation-rmse:6.55080
# [54]	validation-rmse:6.54989
# [55]	validation-rmse:6.54896
# [56]	validation-rmse:6.54775
# [57]	validation-rmse:6.54662
# [58]	validation-rmse:6.54579
# [59]	validation-rmse:6.54466
# [60]	validation-rmse:6.54330
# [61]	validation-rmse:6.54255
# [62]	validation-rmse:6.54194
# [63]	validation-rmse:6.54129
# [64]	validation-rmse:6.54033
# [65]	validation-rmse:6.53939
# [66]	validation-rmse:6.53834
# [67]	validation-rmse:6.53789
# [68]	validation-rmse:6.53737
# [69]	validation-rmse:6.53683
# [70]	validation-rmse:6.53598
# [71]	validation-rmse:6.53511
# [72]	validation-rmse:6.53439
# [73]	validation-rmse:6.53367
# [74]	validation-rmse:6.53316
# [75]	validation-rmse:6.53236
# [76]	validation-rmse:6.53172
# [77]	validation-rmse:6.53129
# [78]	validation-rmse:6.53057
# [79]	validation-rmse:6.53001
# [80]	validation-rmse:6.52983
# [81]	validation-rmse:6.52901
# [82]	validation-rmse:6.52832
# [83]	validation-rmse:6.52783
# [84]	validation-rmse:6.52690
# [85]	validation-rmse:6.52554
# [86]	validation-rmse:6.52401
# [87]	validation-rmse:6.52340
# [88]	validation-rmse:6.52283
# [89]	validation-rmse:6.52240
# [90]	validation-rmse:6.52191
# [91]	validation-rmse:6.52121
# [92]	validation-rmse:6.52049
# [93]	validation-rmse:6.51973
# [94]	validation-rmse:6.51944
# [95]	validation-rmse:6.51903
# [96]	validation-rmse:6.51869
# [97]	validation-rmse:6.51801
# [98]	validation-rmse:6.51738
# [99]	validation-rmse:6.51700
# [100]	validation-rmse:6.51630
# [101]	validation-rmse:6.51597
# [102]	validation-rmse:6.51548
# [103]	validation-rmse:6.51476
# [104]	validation-rmse:6.51429
# [105]	validation-rmse:6.51299
# [106]	validation-rmse:6.51255
# [107]	validation-rmse:6.51212
# [108]	validation-rmse:6.51186
# [109]	validation-rmse:6.51122
# [110]	validation-rmse:6.51095
# [111]	validation-rmse:6.51057
# [112]	validation-rmse:6.51016
# [113]	validation-rmse:6.50977
# [114]	validation-rmse:6.50914
# [115]	validation-rmse:6.50870
# [116]	validation-rmse:6.50816
# [117]	validation-rmse:6.50803
# [118]	validation-rmse:6.50744
# [119]	validation-rmse:6.50707
# [120]	validation-rmse:6.50590
# [121]	validation-rmse:6.50547
# [122]	validation-rmse:6.50505
# [123]	validation-rmse:6.50495
# [124]	validation-rmse:6.50435
# [125]	validation-rmse:6.50401
# [126]	validation-rmse:6.50347
# [127]	validation-rmse:6.50310
# [128]	validation-rmse:6.50253
# [129]	validation-rmse:6.50229
# [130]	validation-rmse:6.50191
# [131]	validation-rmse:6.50133
# [132]	validation-rmse:6.50096
# [133]	validation-rmse:6.50085
# [134]	validation-rmse:6.50037
# [135]	validation-rmse:6.49949
# [136]	validation-rmse:6.49904
# [137]	validation-rmse:6.49862
# [138]	validation-rmse:6.49854
# [139]	validation-rmse:6.49778
# [140]	validation-rmse:6.49755
# [141]	validation-rmse:6.49711
# [142]	validation-rmse:6.49674
# [143]	validation-rmse:6.49641
# [144]	validation-rmse:6.49597
# [145]	validation-rmse:6.49566
# [146]	validation-rmse:6.49525
# [147]	validation-rmse:6.49496
# [148]	validation-rmse:6.49479
# [149]	validation-rmse:6.49449
# [150]	validation-rmse:6.49413
# [151]	validation-rmse:6.49399
# [152]	validation-rmse:6.49383
# [153]	validation-rmse:6.49361
# [154]	validation-rmse:6.49325
# [155]	validation-rmse:6.49279
# [156]	validation-rmse:6.49259
# [157]	validation-rmse:6.49246
# [158]	validation-rmse:6.49190
# [159]	validation-rmse:6.49154
# [160]	validation-rmse:6.49129
# [161]	validation-rmse:6.49029
# [162]	validation-rmse:6.48999
# [163]	validation-rmse:6.48972
# [164]	validation-rmse:6.48935
# [165]	validation-rmse:6.48926
# [166]	validation-rmse:6.48899
# [167]	validation-rmse:6.48875
# [168]	validation-rmse:6.48844
# [169]	validation-rmse:6.48818
# [170]	validation-rmse:6.48800
# [171]	validation-rmse:6.48746
# [172]	validation-rmse:6.48732
# [173]	validation-rmse:6.48702
# [174]	validation-rmse:6.48665
# [175]	validation-rmse:6.48628
# [176]	validation-rmse:6.48607
# [177]	validation-rmse:6.48575
# [178]	validation-rmse:6.48565
# [179]	validation-rmse:6.48541
# [180]	validation-rmse:6.48501
# [181]	validation-rmse:6.48452
# [182]	validation-rmse:6.48417
# [183]	validation-rmse:6.48399
# [184]	validation-rmse:6.48385
# [185]	validation-rmse:6.48351
# [186]	validation-rmse:6.48312
# [187]	validation-rmse:6.48289
# [188]	validation-rmse:6.48279
# [189]	validation-rmse:6.48255
# [190]	validation-rmse:6.48246
# [191]	validation-rmse:6.48195
# [192]	validation-rmse:6.48178
# [193]	validation-rmse:6.48144
# [194]	validation-rmse:6.48103
# [195]	validation-rmse:6.48080
# [196]	validation-rmse:6.48067
# [197]	validation-rmse:6.48046
# [198]	validation-rmse:6.48021
# [199]	validation-rmse:6.48013
# [200]	validation-rmse:6.48005
# [201]	validation-rmse:6.47959
# [202]	validation-rmse:6.47940
# [203]	validation-rmse:6.47932
# [204]	validation-rmse:6.47913
# [205]	validation-rmse:6.47903
# [206]	validation-rmse:6.47884
# [207]	validation-rmse:6.47852
# [208]	validation-rmse:6.47827
# [209]	validation-rmse:6.47803
# [210]	validation-rmse:6.47775
# [211]	validation-rmse:6.47746
# [212]	validation-rmse:6.47732
# [213]	validation-rmse:6.47683
# [214]	validation-rmse:6.47665
# [215]	validation-rmse:6.47649
# [216]	validation-rmse:6.47620
# [217]	validation-rmse:6.47599
# [218]	validation-rmse:6.47595
# [219]	validation-rmse:6.47579
# [220]	validation-rmse:6.47574
# [221]	validation-rmse:6.47554
# [222]	validation-rmse:6.47544
# [223]	validation-rmse:6.47530
# [224]	validation-rmse:6.47517
# [225]	validation-rmse:6.47484
# [226]	validation-rmse:6.47438
# [227]	validation-rmse:6.47414
# [228]	validation-rmse:6.47396
# [229]	validation-rmse:6.47375
# [230]	validation-rmse:6.47304
# [231]	validation-rmse:6.47271
# [232]	validation-rmse:6.47248
# [233]	validation-rmse:6.47226
# [234]	validation-rmse:6.47207
# [235]	validation-rmse:6.47178
# [236]	validation-rmse:6.47160
# [237]	validation-rmse:6.47134
# [238]	validation-rmse:6.47107
# [239]	validation-rmse:6.47098
# [240]	validation-rmse:6.47083
# [241]	validation-rmse:6.47061
# [242]	validation-rmse:6.47037
# [243]	validation-rmse:6.47019
# [244]	validation-rmse:6.47020
# [245]	validation-rmse:6.46990
# [246]	validation-rmse:6.46973
# [247]	validation-rmse:6.46971
# [248]	validation-rmse:6.46957
# [249]	validation-rmse:6.46927
# [250]	validation-rmse:6.46912
# [251]	validation-rmse:6.46889
# [252]	validation-rmse:6.46868
# [253]	validation-rmse:6.46838
# [254]	validation-rmse:6.46827
# [255]	validation-rmse:6.46818
# [256]	validation-rmse:6.46822
# [257]	validation-rmse:6.46803
# [258]	validation-rmse:6.46795
# [259]	validation-rmse:6.46786
# [260]	validation-rmse:6.46763
# [261]	validation-rmse:6.46736
# [262]	validation-rmse:6.46723
# [263]	validation-rmse:6.46676
# [264]	validation-rmse:6.46649
# [265]	validation-rmse:6.46636
# [266]	validation-rmse:6.46619
# [267]	validation-rmse:6.46609
# [268]	validation-rmse:6.46591
# [269]	validation-rmse:6.46565
# [270]	validation-rmse:6.46553
# [271]	validation-rmse:6.46556
# [272]	validation-rmse:6.46534
# [273]	validation-rmse:6.46504
# [274]	validation-rmse:6.46488
# [275]	validation-rmse:6.46486
# [276]	validation-rmse:6.46472
# [277]	validation-rmse:6.46456
# [278]	validation-rmse:6.46442
# [279]	validation-rmse:6.46435
# [280]	validation-rmse:6.46427
# [281]	validation-rmse:6.46422
# [282]	validation-rmse:6.46398
# [283]	validation-rmse:6.46380
# [284]	validation-rmse:6.46362
# [285]	validation-rmse:6.46332
# [286]	validation-rmse:6.46321
# [287]	validation-rmse:6.46310
# [288]	validation-rmse:6.46290
# [289]	validation-rmse:6.46274
# [290]	validation-rmse:6.46253
# [291]	validation-rmse:6.46245
# [292]	validation-rmse:6.46230
# [293]	validation-rmse:6.46210
# [294]	validation-rmse:6.46201
# [295]	validation-rmse:6.46203
# [296]	validation-rmse:6.46195
# [297]	validation-rmse:6.46177
# [298]	validation-rmse:6.46159
# [299]	validation-rmse:6.46151
# [300]	validation-rmse:6.46129
# [301]	validation-rmse:6.46129
# [302]	validation-rmse:6.46119
# [303]	validation-rmse:6.46099
# [304]	validation-rmse:6.46083
# [305]	validation-rmse:6.46069
# [306]	validation-rmse:6.46054
# [307]	validation-rmse:6.46044
# [308]	validation-rmse:6.46018
# [309]	validation-rmse:6.46015
# [310]	validation-rmse:6.45999
# [311]	validation-rmse:6.45977
# [312]	validation-rmse:6.45981
# [313]	validation-rmse:6.45966
# [314]	validation-rmse:6.45957
# [315]	validation-rmse:6.45947
# [316]	validation-rmse:6.45938
# [317]	validation-rmse:6.45929
# [318]	validation-rmse:6.45925
# [319]	validation-rmse:6.45901
# [320]	validation-rmse:6.45888
# [321]	validation-rmse:6.45881
# [322]	validation-rmse:6.45864
# [323]	validation-rmse:6.45837
# [324]	validation-rmse:6.45827
# [325]	validation-rmse:6.45815
# [326]	validation-rmse:6.45797
# [327]	validation-rmse:6.45783
# [328]	validation-rmse:6.45779
# [329]	validation-rmse:6.45763
# [330]	validation-rmse:6.45758
# [331]	validation-rmse:6.45745
# [332]	validation-rmse:6.45738
# [333]	validation-rmse:6.45724
# [334]	validation-rmse:6.45703
# [335]	validation-rmse:6.45685
# [336]	validation-rmse:6.45676
# [337]	validation-rmse:6.45673
# [338]	validation-rmse:6.45652
# [339]	validation-rmse:6.45639
# [340]	validation-rmse:6.45652
# [341]	validation-rmse:6.45622
# [342]	validation-rmse:6.45614
# [343]	validation-rmse:6.45601
# [344]	validation-rmse:6.45597
# [345]	validation-rmse:6.45585
# [346]	validation-rmse:6.45577
# [347]	validation-rmse:6.45566
# [348]	validation-rmse:6.45550
# [349]	validation-rmse:6.45531
# [350]	validation-rmse:6.45527
# [351]	validation-rmse:6.45531
# [352]	validation-rmse:6.45518
# [353]	validation-rmse:6.45510
# [354]	validation-rmse:6.45493
# [355]	validation-rmse:6.45482
# [356]	validation-rmse:6.45451
# [357]	validation-rmse:6.45436
# [358]	validation-rmse:6.45417
# [359]	validation-rmse:6.45407
# [360]	validation-rmse:6.45391
# [361]	validation-rmse:6.45342
# [362]	validation-rmse:6.45323
# [363]	validation-rmse:6.45323
# [364]	validation-rmse:6.45317
# [365]	validation-rmse:6.45310
# [366]	validation-rmse:6.45291
# [367]	validation-rmse:6.45278
# [368]	validation-rmse:6.45275
# [369]	validation-rmse:6.45264
# [370]	validation-rmse:6.45256
# [371]	validation-rmse:6.45250
# [372]	validation-rmse:6.45246
# [373]	validation-rmse:6.45239
# [374]	validation-rmse:6.45228
# [375]	validation-rmse:6.45218
# [376]	validation-rmse:6.45225
# [377]	validation-rmse:6.45235
# [378]	validation-rmse:6.45218
# [379]	validation-rmse:6.45218
# [380]	validation-rmse:6.45190
# [381]	validation-rmse:6.45170
# [382]	validation-rmse:6.45138
# [383]	validation-rmse:6.45101
# [384]	validation-rmse:6.45098
# [385]	validation-rmse:6.45091
# [386]	validation-rmse:6.45088
# [387]	validation-rmse:6.45093
# [388]	validation-rmse:6.45084
# [389]	validation-rmse:6.45073
# [390]	validation-rmse:6.45040
# [391]	validation-rmse:6.45018
# [392]	validation-rmse:6.45004
# [393]	validation-rmse:6.44999
# [394]	validation-rmse:6.44971
# [395]	validation-rmse:6.44958
# [396]	validation-rmse:6.44960
# [397]	validation-rmse:6.44949
# [398]	validation-rmse:6.44927
# [399]	validation-rmse:6.44904
# [400]	validation-rmse:6.44894
# [401]	validation-rmse:6.44893
# [402]	validation-rmse:6.44881
# [403]	validation-rmse:6.44863
# [404]	validation-rmse:6.44856
# [405]	validation-rmse:6.44843
# [406]	validation-rmse:6.44836
# [407]	validation-rmse:6.44843
# [408]	validation-rmse:6.44834
# [409]	validation-rmse:6.44831
# [410]	validation-rmse:6.44818
# [411]	validation-rmse:6.44811
# [412]	validation-rmse:6.44814
# [413]	validation-rmse:6.44810
# [414]	validation-rmse:6.44794
# [415]	validation-rmse:6.44782
# [416]	validation-rmse:6.44779
# [417]	validation-rmse:6.44755
# [418]	validation-rmse:6.44753
# [419]	validation-rmse:6.44734
# [420]	validation-rmse:6.44726
# [421]	validation-rmse:6.44710
# [422]	validation-rmse:6.44707
# [423]	validation-rmse:6.44694
# [424]	validation-rmse:6.44693
# [425]	validation-rmse:6.44665
# [426]	validation-rmse:6.44653
# [427]	validation-rmse:6.44647
# [428]	validation-rmse:6.44633
# [429]	validation-rmse:6.44613
# [430]	validation-rmse:6.44618
# [431]	validation-rmse:6.44607
# [432]	validation-rmse:6.44596
# [433]	validation-rmse:6.44590
# [434]	validation-rmse:6.44584
# [435]	validation-rmse:6.44579
# [436]	validation-rmse:6.44565
# [437]	validation-rmse:6.44561
# [438]	validation-rmse:6.44556
# [439]	validation-rmse:6.44552
# [440]	validation-rmse:6.44545
# [441]	validation-rmse:6.44546
# [442]	validation-rmse:6.44548
# [443]	validation-rmse:6.44534
# [444]	validation-rmse:6.44505
# [445]	validation-rmse:6.44495
# [446]	validation-rmse:6.44469
# [447]	validation-rmse:6.44449
# [448]	validation-rmse:6.44448
# [449]	validation-rmse:6.44445
# [450]	validation-rmse:6.44446
# [451]	validation-rmse:6.44430
# [452]	validation-rmse:6.44430
# [453]	validation-rmse:6.44413
# [454]	validation-rmse:6.44412
# [455]	validation-rmse:6.44407
# [456]	validation-rmse:6.44392
# [457]	validation-rmse:6.44380
# [458]	validation-rmse:6.44384
# [459]	validation-rmse:6.44366
# [460]	validation-rmse:6.44364
# [461]	validation-rmse:6.44355
# [462]	validation-rmse:6.44349
# [463]	validation-rmse:6.44337
# [464]	validation-rmse:6.44329
# [465]	validation-rmse:6.44338
# [466]	validation-rmse:6.44328
# [467]	validation-rmse:6.44322
# [468]	validation-rmse:6.44317
# [469]	validation-rmse:6.44310
# [470]	validation-rmse:6.44307
# [471]	validation-rmse:6.44284
# [472]	validation-rmse:6.44282
# [473]	validation-rmse:6.44297
# [474]	validation-rmse:6.44277
# [475]	validation-rmse:6.44270
# [476]	validation-rmse:6.44265
# [477]	validation-rmse:6.44260
# [478]	validation-rmse:6.44259
# [479]	validation-rmse:6.44248
# [480]	validation-rmse:6.44253
# [481]	validation-rmse:6.44251
# [482]	validation-rmse:6.44241
# [483]	validation-rmse:6.44237
# [484]	validation-rmse:6.44236
# [485]	validation-rmse:6.44230
# [486]	validation-rmse:6.44220
# [487]	validation-rmse:6.44217
# [488]	validation-rmse:6.44215
# [489]	validation-rmse:6.44205
# [490]	validation-rmse:6.44186
# [491]	validation-rmse:6.44175
# [492]	validation-rmse:6.44170
# [493]	validation-rmse:6.44160
# [494]	validation-rmse:6.44150
# [495]	validation-rmse:6.44119
# [496]	validation-rmse:6.44079
# [497]	validation-rmse:6.44059
# [498]	validation-rmse:6.44053
# [499]	validation-rmse:6.44045
# [500]	validation-rmse:6.44041
# [501]	validation-rmse:6.44042
# [502]	validation-rmse:6.44001
# [503]	validation-rmse:6.43996
# [504]	validation-rmse:6.43996
# [505]	validation-rmse:6.43991
# [506]	validation-rmse:6.43989
# [507]	validation-rmse:6.43982
# [508]	validation-rmse:6.43952
# [509]	validation-rmse:6.43941
# [510]	validation-rmse:6.43939
# [511]	validation-rmse:6.43919
# [512]	validation-rmse:6.43918
# [513]	validation-rmse:6.43915
# [514]	validation-rmse:6.43848
# [515]	validation-rmse:6.43830
# [516]	validation-rmse:6.43820
# [517]	validation-rmse:6.43817
# [518]	validation-rmse:6.43802
# [519]	validation-rmse:6.43800
# [520]	validation-rmse:6.43789
# [521]	validation-rmse:6.43786
# [522]	validation-rmse:6.43785
# [523]	validation-rmse:6.43775
# [524]	validation-rmse:6.43771
# [525]	validation-rmse:6.43772
# [526]	validation-rmse:6.43767
# [527]	validation-rmse:6.43766
# [528]	validation-rmse:6.43738
# [529]	validation-rmse:6.43708
# [530]	validation-rmse:6.43706
# [531]	validation-rmse:6.43706
# [532]	validation-rmse:6.43703
# [533]	validation-rmse:6.43699
# [534]	validation-rmse:6.43691
# [535]	validation-rmse:6.43681
# [536]	validation-rmse:6.43683
# [537]	validation-rmse:6.43684
# [538]	validation-rmse:6.43674
# [539]	validation-rmse:6.43630
# [540]	validation-rmse:6.43627
# [541]	validation-rmse:6.43619
# [542]	validation-rmse:6.43619
# [543]	validation-rmse:6.43615
# [544]	validation-rmse:6.43617
# [545]	validation-rmse:6.43594
# [546]	validation-rmse:6.43590
# [547]	validation-rmse:6.43599
# [548]	validation-rmse:6.43596
# [549]	validation-rmse:6.43589
# [550]	validation-rmse:6.43585
# [551]	validation-rmse:6.43579
# [552]	validation-rmse:6.43565
# [553]	validation-rmse:6.43564
# [554]	validation-rmse:6.43558
# [555]	validation-rmse:6.43552
# [556]	validation-rmse:6.43551
# [557]	validation-rmse:6.43545
# [558]	validation-rmse:6.43540
# [559]	validation-rmse:6.43536
# [560]	validation-rmse:6.43532
# [561]	validation-rmse:6.43529
# [562]	validation-rmse:6.43519
# [563]	validation-rmse:6.43518
# [564]	validation-rmse:6.43516
# [565]	validation-rmse:6.43510
# [566]	validation-rmse:6.43517
# [567]	validation-rmse:6.43507
# [568]	validation-rmse:6.43478
# [569]	validation-rmse:6.43479
# [570]	validation-rmse:6.43485
# [571]	validation-rmse:6.43449
# [572]	validation-rmse:6.43435
# [573]	validation-rmse:6.43441
# [574]	validation-rmse:6.43454
# [575]	validation-rmse:6.43445
# [576]	validation-rmse:6.43427
# [577]	validation-rmse:6.43427
# [578]	validation-rmse:6.43439
# [579]	validation-rmse:6.43420
# [580]	validation-rmse:6.43418
# [581]	validation-rmse:6.43419
# [582]	validation-rmse:6.43412
# [583]	validation-rmse:6.43416
# [584]	validation-rmse:6.43414
# [585]	validation-rmse:6.43430
# [586]	validation-rmse:6.43418
# [587]	validation-rmse:6.43412
# [588]	validation-rmse:6.43406
# [589]	validation-rmse:6.43397
# [590]	validation-rmse:6.43391
# [591]	validation-rmse:6.43387
# [592]	validation-rmse:6.43381
# [593]	validation-rmse:6.43371
# [594]	validation-rmse:6.43362
# [595]	validation-rmse:6.43347
# [596]	validation-rmse:6.43345
# [597]	validation-rmse:6.43334
# [598]	validation-rmse:6.43299
# [599]	validation-rmse:6.43272
# [600]	validation-rmse:6.43272
# [601]	validation-rmse:6.43265
# [602]	validation-rmse:6.43270
# [603]	validation-rmse:6.43262
# [604]	validation-rmse:6.43255
# [605]	validation-rmse:6.43284
# [606]	validation-rmse:6.43285
# [607]	validation-rmse:6.43277
# [608]	validation-rmse:6.43280
# [609]	validation-rmse:6.43279
# [610]	validation-rmse:6.43279
# [611]	validation-rmse:6.43256
# [612]	validation-rmse:6.43255
# [613]	validation-rmse:6.43256
# [614]	validation-rmse:6.43253
# [615]	validation-rmse:6.43259
# [616]	validation-rmse:6.43253
# [617]	validation-rmse:6.43248
# [618]	validation-rmse:6.43246
# [619]	validation-rmse:6.43238
# [620]	validation-rmse:6.43222
# [621]	validation-rmse:6.43212
# [622]	validation-rmse:6.43281
# [623]	validation-rmse:6.43277
# [624]	validation-rmse:6.43265
# [625]	validation-rmse:6.43262
# [626]	validation-rmse:6.43261
# [627]	validation-rmse:6.43263
# [628]	validation-rmse:6.43235
# [629]	validation-rmse:6.43188
# [630]	validation-rmse:6.43125
# [631]	validation-rmse:6.43109
# [632]	validation-rmse:6.43067
# [633]	validation-rmse:6.43048
# [634]	validation-rmse:6.43016
# [635]	validation-rmse:6.42996
# [636]	validation-rmse:6.42974
# [637]	validation-rmse:6.42955
# [638]	validation-rmse:6.42947
# [639]	validation-rmse:6.42935
# [640]	validation-rmse:6.42936
# [641]	validation-rmse:6.42947
# [642]	validation-rmse:6.42933
# [643]	validation-rmse:6.42922
# [644]	validation-rmse:6.42924
# [645]	validation-rmse:6.42934
# [646]	validation-rmse:6.42935
# [647]	validation-rmse:6.42915
# [648]	validation-rmse:6.42913
# [649]	validation-rmse:6.42907
# [650]	validation-rmse:6.42901
# [651]	validation-rmse:6.42897
# [652]	validation-rmse:6.42901
# [653]	validation-rmse:6.42897
# [654]	validation-rmse:6.42920
# [655]	validation-rmse:6.42911
# [656]	validation-rmse:6.42888
# [657]	validation-rmse:6.42874
# [658]	validation-rmse:6.42864
# [659]	validation-rmse:6.42872
# [660]	validation-rmse:6.42809
# [661]	validation-rmse:6.42823
# [662]	validation-rmse:6.42821
# [663]	validation-rmse:6.42822
# [664]	validation-rmse:6.42817
# [665]	validation-rmse:6.42825
# [666]	validation-rmse:6.42800
# [667]	validation-rmse:6.42795
# [668]	validation-rmse:6.42789
# [669]	validation-rmse:6.42788
# [670]	validation-rmse:6.42792
# [671]	validation-rmse:6.42796
# [672]	validation-rmse:6.42794
# [673]	validation-rmse:6.42797
# [674]	validation-rmse:6.42796
# [675]	validation-rmse:6.42793
# [676]	validation-rmse:6.42788
# [677]	validation-rmse:6.42776
# [678]	validation-rmse:6.42755
# [679]	validation-rmse:6.42841
# [680]	validation-rmse:6.42840
# [681]	validation-rmse:6.42839
# [682]	validation-rmse:6.42841
# [683]	validation-rmse:6.42834
# [684]	validation-rmse:6.42823
# [685]	validation-rmse:6.42817
# [686]	validation-rmse:6.42807
# [687]	validation-rmse:6.42804
# [688]	validation-rmse:6.42807
# [689]	validation-rmse:6.42804
# [690]	validation-rmse:6.42796
# [691]	validation-rmse:6.42795
# [692]	validation-rmse:6.42796
# [693]	validation-rmse:6.42790
# [694]	validation-rmse:6.42786
# [695]	validation-rmse:6.42781
# [696]	validation-rmse:6.42776
# [697]	validation-rmse:6.42775
# [698]	validation-rmse:6.42767
# [699]	validation-rmse:6.42769
# [700]	validation-rmse:6.42777
# [701]	validation-rmse:6.42777
# [702]	validation-rmse:6.42773
# [703]	validation-rmse:6.42768
# [704]	validation-rmse:6.42762
# [705]	validation-rmse:6.42759
# [706]	validation-rmse:6.42739
# [707]	validation-rmse:6.42817
# [708]	validation-rmse:6.42820
# [709]	validation-rmse:6.42830
# [710]	validation-rmse:6.42851
# [711]	validation-rmse:6.42857
# [712]	validation-rmse:6.42859
# [713]	validation-rmse:6.42861
# [714]	validation-rmse:6.42862
# [715]	validation-rmse:6.42867
# [716]	validation-rmse:6.42869
# [717]	validation-rmse:6.42864
# [718]	validation-rmse:6.42861
# [719]	validation-rmse:6.42855
# [720]	validation-rmse:6.42854
# [721]	validation-rmse:6.42868
# [722]	validation-rmse:6.42872
# [723]	validation-rmse:6.42865
# [724]	validation-rmse:6.42865
# [725]	validation-rmse:6.42860
# [726]	validation-rmse:6.42860
# [727]	validation-rmse:6.42845
# [728]	validation-rmse:6.42841
# [729]	validation-rmse:6.42839
# [730]	validation-rmse:6.42839
# [731]	validation-rmse:6.42844
# [732]	validation-rmse:6.42847
# [733]	validation-rmse:6.42824
# [734]	validation-rmse:6.42824
# [735]	validation-rmse:6.42824
# [736]	validation-rmse:6.42825
# [737]	validation-rmse:6.42818
# [738]	validation-rmse:6.42821
# [739]	validation-rmse:6.42814
# [740]	validation-rmse:6.42806
# [741]	validation-rmse:6.42809
# [742]	validation-rmse:6.42823
# [743]	validation-rmse:6.42822
# [744]	validation-rmse:6.42810
# [745]	validation-rmse:6.42806
# [746]	validation-rmse:6.42821
# [747]	validation-rmse:6.42822
# [748]	validation-rmse:6.42819
# [749]	validation-rmse:6.42812
# [750]	validation-rmse:6.42804
# [751]	validation-rmse:6.42800
# [752]	validation-rmse:6.42801
# [753]	validation-rmse:6.42795
# [754]	validation-rmse:6.42795
# [755]	validation-rmse:6.42787
# [756]	validation-rmse:6.42774

# %%
with mlflow.start_run():
    
    train = xgb.DMatrix(X_train, label=y_train)
    valid = xgb.DMatrix(X_val, label=y_val)

    best_params = {
        'learning_rate': 0.09585355369315604,
        'max_depth': 30,
        'min_child_weight': 1.060597050922164,
        'objective': 'reg:linear',
        'reg_alpha': 0.018060244040060163,
        'reg_lambda': 0.011658731377413597,
        'seed': 42
    }

    mlflow.log_params(best_params)

    booster = xgb.train(
        params=best_params,
        dtrain=train,
        num_boost_round=1000,
        evals=[(valid, 'validation')],
        early_stopping_rounds=50
    )

    y_pred = booster.predict(valid)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)

    with open("models/preprocessor.b", "wb") as f_out:
        pickle.dump(dv, f_out)
    mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

    mlflow.xgboost.log_model(booster, artifact_path="models_mlflow")
# Out:
# [17:06:05] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:19.48425
# [1]	validation-rmse:17.95635
# [2]	validation-rmse:16.59103
# [3]	validation-rmse:15.37412
# [4]	validation-rmse:14.29029
# [5]	validation-rmse:13.32807
# [6]	validation-rmse:12.47571
# [7]	validation-rmse:11.72138
# [8]	validation-rmse:11.05825
# [9]	validation-rmse:10.47535
# [10]	validation-rmse:9.96449
# [11]	validation-rmse:9.51756
# [12]	validation-rmse:9.12641
# [13]	validation-rmse:8.78569
# [14]	validation-rmse:8.49089
# [15]	validation-rmse:8.23445
# [16]	validation-rmse:8.01207
# [17]	validation-rmse:7.81886
# [18]	validation-rmse:7.65169
# [19]	validation-rmse:7.50672
# [20]	validation-rmse:7.38153
# [21]	validation-rmse:7.27299
# [22]	validation-rmse:7.17863
# [23]	validation-rmse:7.09718
# [24]	validation-rmse:7.02603
# [25]	validation-rmse:6.96344
# [26]	validation-rmse:6.90935
# [27]	validation-rmse:6.86285
# [28]	validation-rmse:6.82157
# [29]	validation-rmse:6.78486
# [30]	validation-rmse:6.75283
# [31]	validation-rmse:6.72433
# [32]	validation-rmse:6.69838
# [33]	validation-rmse:6.67599
# [34]	validation-rmse:6.65632
# [35]	validation-rmse:6.63968
# [36]	validation-rmse:6.62456
# [37]	validation-rmse:6.61030
# [38]	validation-rmse:6.59833
# [39]	validation-rmse:6.58671
# [40]	validation-rmse:6.57678
# [41]	validation-rmse:6.56792
# [42]	validation-rmse:6.56024
# [43]	validation-rmse:6.55307
# [44]	validation-rmse:6.54644
# [45]	validation-rmse:6.54087
# [46]	validation-rmse:6.53587
# [47]	validation-rmse:6.53128
# [48]	validation-rmse:6.52719
# [49]	validation-rmse:6.52427
# [50]	validation-rmse:6.52098
# [51]	validation-rmse:6.51875
# [52]	validation-rmse:6.51547
# [53]	validation-rmse:6.51333
# [54]	validation-rmse:6.51034
# [55]	validation-rmse:6.50826
# [56]	validation-rmse:6.50668
# [57]	validation-rmse:6.50477
# [58]	validation-rmse:6.50288
# [59]	validation-rmse:6.50114
# [60]	validation-rmse:6.49931
# [61]	validation-rmse:6.49758
# [62]	validation-rmse:6.49577
# [63]	validation-rmse:6.49364
# [64]	validation-rmse:6.49179
# [65]	validation-rmse:6.49031
# [66]	validation-rmse:6.48955
# [67]	validation-rmse:6.48814
# [68]	validation-rmse:6.48684
# [69]	validation-rmse:6.48526
# [70]	validation-rmse:6.48384
# [71]	validation-rmse:6.48249
# [72]	validation-rmse:6.48180
# [73]	validation-rmse:6.48127
# [74]	validation-rmse:6.48053
# [75]	validation-rmse:6.47965
# [76]	validation-rmse:6.47878
# [77]	validation-rmse:6.47808
# [78]	validation-rmse:6.47695
# [79]	validation-rmse:6.47605
# [80]	validation-rmse:6.47528
# [81]	validation-rmse:6.47416
# [82]	validation-rmse:6.47331
# [83]	validation-rmse:6.47237
# [84]	validation-rmse:6.47146
# [85]	validation-rmse:6.47022
# [86]	validation-rmse:6.46934
# [87]	validation-rmse:6.46830
# [88]	validation-rmse:6.46799
# [89]	validation-rmse:6.46740
# [90]	validation-rmse:6.46645
# [91]	validation-rmse:6.46556
# [92]	validation-rmse:6.46451
# [93]	validation-rmse:6.46355
# [94]	validation-rmse:6.46222
# [95]	validation-rmse:6.46134
# [96]	validation-rmse:6.46099
# [97]	validation-rmse:6.46062
# [98]	validation-rmse:6.46009
# [99]	validation-rmse:6.45985
# [100]	validation-rmse:6.45925
# [101]	validation-rmse:6.45879
# [102]	validation-rmse:6.45800
# [103]	validation-rmse:6.45743
# [104]	validation-rmse:6.45704
# [105]	validation-rmse:6.45635
# [106]	validation-rmse:6.45573
# [107]	validation-rmse:6.45514
# [108]	validation-rmse:6.45445
# [109]	validation-rmse:6.45347
# [110]	validation-rmse:6.45290
# [111]	validation-rmse:6.45212
# [112]	validation-rmse:6.45163
# [113]	validation-rmse:6.45093
# [114]	validation-rmse:6.45017
# [115]	validation-rmse:6.44938
# [116]	validation-rmse:6.44860
# [117]	validation-rmse:6.44821
# [118]	validation-rmse:6.44777
# [119]	validation-rmse:6.44728
# [120]	validation-rmse:6.44657
# [121]	validation-rmse:6.44601
# [122]	validation-rmse:6.44529
# [123]	validation-rmse:6.44467
# [124]	validation-rmse:6.44404
# [125]	validation-rmse:6.44343
# [126]	validation-rmse:6.44295
# [127]	validation-rmse:6.44240
# [128]	validation-rmse:6.44131
# [129]	validation-rmse:6.44066
# [130]	validation-rmse:6.44046
# [131]	validation-rmse:6.44021
# [132]	validation-rmse:6.43979
# [133]	validation-rmse:6.43959
# [134]	validation-rmse:6.43907
# [135]	validation-rmse:6.43873
# [136]	validation-rmse:6.43819
# [137]	validation-rmse:6.43754
# [138]	validation-rmse:6.43688
# [139]	validation-rmse:6.43666
# [140]	validation-rmse:6.43625
# [141]	validation-rmse:6.43587
# [142]	validation-rmse:6.43529
# [143]	validation-rmse:6.43475
# [144]	validation-rmse:6.43418
# [145]	validation-rmse:6.43377
# [146]	validation-rmse:6.43293
# [147]	validation-rmse:6.43239
# [148]	validation-rmse:6.43176
# [149]	validation-rmse:6.43148
# [150]	validation-rmse:6.43092
# [151]	validation-rmse:6.43041
# [152]	validation-rmse:6.42996
# [153]	validation-rmse:6.42932
# [154]	validation-rmse:6.42880
# [155]	validation-rmse:6.42823
# [156]	validation-rmse:6.42773
# [157]	validation-rmse:6.42761
# [158]	validation-rmse:6.42725
# [159]	validation-rmse:6.42669
# [160]	validation-rmse:6.42627
# [161]	validation-rmse:6.42591
# [162]	validation-rmse:6.42540
# [163]	validation-rmse:6.42489
# [164]	validation-rmse:6.42425
# [165]	validation-rmse:6.42393
# [166]	validation-rmse:6.42328
# [167]	validation-rmse:6.42269
# [168]	validation-rmse:6.42239
# [169]	validation-rmse:6.42194
# [170]	validation-rmse:6.42133
# [171]	validation-rmse:6.42085
# [172]	validation-rmse:6.42040
# [173]	validation-rmse:6.42020
# [174]	validation-rmse:6.42002
# [175]	validation-rmse:6.41973
# [176]	validation-rmse:6.41935
# [177]	validation-rmse:6.41909
# [178]	validation-rmse:6.41862
# [179]	validation-rmse:6.41843
# [180]	validation-rmse:6.41814
# [181]	validation-rmse:6.41735
# [182]	validation-rmse:6.41708
# [183]	validation-rmse:6.41635
# [184]	validation-rmse:6.41627
# [185]	validation-rmse:6.41602
# [186]	validation-rmse:6.41555
# [187]	validation-rmse:6.41550
# [188]	validation-rmse:6.41493
# [189]	validation-rmse:6.41447
# [190]	validation-rmse:6.41404
# [191]	validation-rmse:6.41373
# [192]	validation-rmse:6.41320
# [193]	validation-rmse:6.41298
# [194]	validation-rmse:6.41244
# [195]	validation-rmse:6.41195
# [196]	validation-rmse:6.41166
# [197]	validation-rmse:6.41113
# [198]	validation-rmse:6.41093
# [199]	validation-rmse:6.41061
# [200]	validation-rmse:6.41026
# [201]	validation-rmse:6.40990
# [202]	validation-rmse:6.40940
# [203]	validation-rmse:6.40898
# [204]	validation-rmse:6.40863
# [205]	validation-rmse:6.40824
# [206]	validation-rmse:6.40782
# [207]	validation-rmse:6.40755
# [208]	validation-rmse:6.40740
# [209]	validation-rmse:6.40724
# [210]	validation-rmse:6.40683
# [211]	validation-rmse:6.40635
# [212]	validation-rmse:6.40611
# [213]	validation-rmse:6.40549
# [214]	validation-rmse:6.40514
# [215]	validation-rmse:6.40505
# [216]	validation-rmse:6.40449
# [217]	validation-rmse:6.40426
# [218]	validation-rmse:6.40389
# [219]	validation-rmse:6.40355
# [220]	validation-rmse:6.40308
# [221]	validation-rmse:6.40265
# [222]	validation-rmse:6.40237
# [223]	validation-rmse:6.40215
# [224]	validation-rmse:6.40170
# [225]	validation-rmse:6.40138
# [226]	validation-rmse:6.40104
# [227]	validation-rmse:6.40049
# [228]	validation-rmse:6.40016
# [229]	validation-rmse:6.40000
# [230]	validation-rmse:6.39987
# [231]	validation-rmse:6.39984
# [232]	validation-rmse:6.39941
# [233]	validation-rmse:6.39937
# [234]	validation-rmse:6.39908
# [235]	validation-rmse:6.39884
# [236]	validation-rmse:6.39855
# [237]	validation-rmse:6.39841
# [238]	validation-rmse:6.39801
# [239]	validation-rmse:6.39775
# [240]	validation-rmse:6.39711
# [241]	validation-rmse:6.39684
# [242]	validation-rmse:6.39660
# [243]	validation-rmse:6.39635
# [244]	validation-rmse:6.39624
# [245]	validation-rmse:6.39600
# [246]	validation-rmse:6.39555
# [247]	validation-rmse:6.39556
# [248]	validation-rmse:6.39523
# [249]	validation-rmse:6.39468
# [250]	validation-rmse:6.39437
# [251]	validation-rmse:6.39432
# [252]	validation-rmse:6.39394
# [253]	validation-rmse:6.39375
# [254]	validation-rmse:6.39326
# [255]	validation-rmse:6.39297
# [256]	validation-rmse:6.39265
# [257]	validation-rmse:6.39239
# [258]	validation-rmse:6.39185
# [259]	validation-rmse:6.39174
# [260]	validation-rmse:6.39146
# [261]	validation-rmse:6.39103
# [262]	validation-rmse:6.39096
# [263]	validation-rmse:6.39070
# [264]	validation-rmse:6.39035
# [265]	validation-rmse:6.39008
# [266]	validation-rmse:6.38964
# [267]	validation-rmse:6.38933
# [268]	validation-rmse:6.38887
# [269]	validation-rmse:6.38880
# [270]	validation-rmse:6.38841
# [271]	validation-rmse:6.38790
# [272]	validation-rmse:6.38785
# [273]	validation-rmse:6.38760
# [274]	validation-rmse:6.38752
# [275]	validation-rmse:6.38711
# [276]	validation-rmse:6.38693
# [277]	validation-rmse:6.38679
# [278]	validation-rmse:6.38631
# [279]	validation-rmse:6.38589
# [280]	validation-rmse:6.38573
# [281]	validation-rmse:6.38517
# [282]	validation-rmse:6.38490
# [283]	validation-rmse:6.38479
# [284]	validation-rmse:6.38458
# [285]	validation-rmse:6.38413
# [286]	validation-rmse:6.38405
# [287]	validation-rmse:6.38383
# [288]	validation-rmse:6.38357
# [289]	validation-rmse:6.38302
# [290]	validation-rmse:6.38281
# [291]	validation-rmse:6.38251
# [292]	validation-rmse:6.38235
# [293]	validation-rmse:6.38202
# [294]	validation-rmse:6.38163
# [295]	validation-rmse:6.38126
# [296]	validation-rmse:6.38063
# [297]	validation-rmse:6.38038
# [298]	validation-rmse:6.37990
# [299]	validation-rmse:6.37973
# [300]	validation-rmse:6.37959
# [301]	validation-rmse:6.37926
# [302]	validation-rmse:6.37923
# [303]	validation-rmse:6.37911
# [304]	validation-rmse:6.37905
# [305]	validation-rmse:6.37882
# [306]	validation-rmse:6.37886
# [307]	validation-rmse:6.37864
# [308]	validation-rmse:6.37830
# [309]	validation-rmse:6.37806
# [310]	validation-rmse:6.37790
# [311]	validation-rmse:6.37783
# [312]	validation-rmse:6.37759
# [313]	validation-rmse:6.37705
# [314]	validation-rmse:6.37633
# [315]	validation-rmse:6.37613
# [316]	validation-rmse:6.37577
# [317]	validation-rmse:6.37557
# [318]	validation-rmse:6.37559
# [319]	validation-rmse:6.37545
# [320]	validation-rmse:6.37546
# [321]	validation-rmse:6.37533
# [322]	validation-rmse:6.37506
# [323]	validation-rmse:6.37498
# [324]	validation-rmse:6.37466
# [325]	validation-rmse:6.37432
# [326]	validation-rmse:6.37409
# [327]	validation-rmse:6.37406
# [328]	validation-rmse:6.37381
# [329]	validation-rmse:6.37349
# [330]	validation-rmse:6.37332
# [331]	validation-rmse:6.37311
# [332]	validation-rmse:6.37278
# [333]	validation-rmse:6.37268
# [334]	validation-rmse:6.37249
# [335]	validation-rmse:6.37187
# [336]	validation-rmse:6.37168
# [337]	validation-rmse:6.37150
# [338]	validation-rmse:6.37124
# [339]	validation-rmse:6.37104
# [340]	validation-rmse:6.37081
# [341]	validation-rmse:6.37070
# [342]	validation-rmse:6.37059
# [343]	validation-rmse:6.37034
# [344]	validation-rmse:6.36989
# [345]	validation-rmse:6.36968
# [346]	validation-rmse:6.36942
# [347]	validation-rmse:6.36900
# [348]	validation-rmse:6.36883
# [349]	validation-rmse:6.36881
# [350]	validation-rmse:6.36878
# [351]	validation-rmse:6.36870
# [352]	validation-rmse:6.36836
# [353]	validation-rmse:6.36819
# [354]	validation-rmse:6.36800
# [355]	validation-rmse:6.36786
# [356]	validation-rmse:6.36741
# [357]	validation-rmse:6.36708
# [358]	validation-rmse:6.36708
# [359]	validation-rmse:6.36690
# [360]	validation-rmse:6.36662
# [361]	validation-rmse:6.36647
# [362]	validation-rmse:6.36609
# [363]	validation-rmse:6.36593
# [364]	validation-rmse:6.36571
# [365]	validation-rmse:6.36554
# [366]	validation-rmse:6.36539
# [367]	validation-rmse:6.36530
# [368]	validation-rmse:6.36509
# [369]	validation-rmse:6.36481
# [370]	validation-rmse:6.36468
# [371]	validation-rmse:6.36446
# [372]	validation-rmse:6.36426
# [373]	validation-rmse:6.36403
# [374]	validation-rmse:6.36392
# [375]	validation-rmse:6.36349
# [376]	validation-rmse:6.36331
# [377]	validation-rmse:6.36320
# [378]	validation-rmse:6.36296
# [379]	validation-rmse:6.36266
# [380]	validation-rmse:6.36229
# [381]	validation-rmse:6.36213
# [382]	validation-rmse:6.36202
# [383]	validation-rmse:6.36187
# [384]	validation-rmse:6.36163
# [385]	validation-rmse:6.36137
# [386]	validation-rmse:6.36123
# [387]	validation-rmse:6.36116
# [388]	validation-rmse:6.36094
# [389]	validation-rmse:6.36091
# [390]	validation-rmse:6.36074
# [391]	validation-rmse:6.36075
# [392]	validation-rmse:6.36060
# [393]	validation-rmse:6.36057
# [394]	validation-rmse:6.36038
# [395]	validation-rmse:6.36006
# [396]	validation-rmse:6.35981
# [397]	validation-rmse:6.35966
# [398]	validation-rmse:6.35950
# [399]	validation-rmse:6.35933
# [400]	validation-rmse:6.35930
# [401]	validation-rmse:6.35892
# [402]	validation-rmse:6.35879
# [403]	validation-rmse:6.35839
# [404]	validation-rmse:6.35820
# [405]	validation-rmse:6.35818
# [406]	validation-rmse:6.35804
# [407]	validation-rmse:6.35806
# [408]	validation-rmse:6.35798
# [409]	validation-rmse:6.35805
# [410]	validation-rmse:6.35781
# [411]	validation-rmse:6.35744
# [412]	validation-rmse:6.35733
# [413]	validation-rmse:6.35725
# [414]	validation-rmse:6.35718
# [415]	validation-rmse:6.35679
# [416]	validation-rmse:6.35661
# [417]	validation-rmse:6.35632
# [418]	validation-rmse:6.35615
# [419]	validation-rmse:6.35585
# [420]	validation-rmse:6.35581
# [421]	validation-rmse:6.35546
# [422]	validation-rmse:6.35500
# [423]	validation-rmse:6.35490
# [424]	validation-rmse:6.35478
# [425]	validation-rmse:6.35434
# [426]	validation-rmse:6.35409
# [427]	validation-rmse:6.35399
# [428]	validation-rmse:6.35401
# [429]	validation-rmse:6.35374
# [430]	validation-rmse:6.35360
# [431]	validation-rmse:6.35346
# [432]	validation-rmse:6.35333
# [433]	validation-rmse:6.35315
# [434]	validation-rmse:6.35309
# [435]	validation-rmse:6.35280
# [436]	validation-rmse:6.35266
# [437]	validation-rmse:6.35244
# [438]	validation-rmse:6.35247
# [439]	validation-rmse:6.35225
# [440]	validation-rmse:6.35215
# [441]	validation-rmse:6.35188
# [442]	validation-rmse:6.35170
# [443]	validation-rmse:6.35154
# [444]	validation-rmse:6.35145
# [445]	validation-rmse:6.35121
# [446]	validation-rmse:6.35115
# [447]	validation-rmse:6.35086
# [448]	validation-rmse:6.35072
# [449]	validation-rmse:6.35042
# [450]	validation-rmse:6.35030
# [451]	validation-rmse:6.35006
# [452]	validation-rmse:6.34996
# [453]	validation-rmse:6.34996
# [454]	validation-rmse:6.34986
# [455]	validation-rmse:6.34967
# [456]	validation-rmse:6.34934
# [457]	validation-rmse:6.34935
# [458]	validation-rmse:6.34906
# [459]	validation-rmse:6.34897
# [460]	validation-rmse:6.34892
# [461]	validation-rmse:6.34878
# [462]	validation-rmse:6.34862
# [463]	validation-rmse:6.34847
# [464]	validation-rmse:6.34846
# [465]	validation-rmse:6.34841
# [466]	validation-rmse:6.34799
# [467]	validation-rmse:6.34791
# [468]	validation-rmse:6.34788
# [469]	validation-rmse:6.34763
# [470]	validation-rmse:6.34731
# [471]	validation-rmse:6.34692
# [472]	validation-rmse:6.34673
# [473]	validation-rmse:6.34659
# [474]	validation-rmse:6.34654
# [475]	validation-rmse:6.34639
# [476]	validation-rmse:6.34616
# [477]	validation-rmse:6.34596
# [478]	validation-rmse:6.34582
# [479]	validation-rmse:6.34568
# [480]	validation-rmse:6.34556
# [481]	validation-rmse:6.34549
# [482]	validation-rmse:6.34543
# [483]	validation-rmse:6.34524
# [484]	validation-rmse:6.34518
# [485]	validation-rmse:6.34504
# [486]	validation-rmse:6.34473
# [487]	validation-rmse:6.34470
# [488]	validation-rmse:6.34469
# [489]	validation-rmse:6.34448
# [490]	validation-rmse:6.34428
# [491]	validation-rmse:6.34426
# [492]	validation-rmse:6.34422
# [493]	validation-rmse:6.34407
# [494]	validation-rmse:6.34388
# [495]	validation-rmse:6.34357
# [496]	validation-rmse:6.34345
# [497]	validation-rmse:6.34356
# [498]	validation-rmse:6.34342
# [499]	validation-rmse:6.34336
# [500]	validation-rmse:6.34316
# [501]	validation-rmse:6.34320
# [502]	validation-rmse:6.34300
# [503]	validation-rmse:6.34287
# [504]	validation-rmse:6.34258
# [505]	validation-rmse:6.34260
# [506]	validation-rmse:6.34262
# [507]	validation-rmse:6.34243
# [508]	validation-rmse:6.34242
# [509]	validation-rmse:6.34230
# [510]	validation-rmse:6.34190
# [511]	validation-rmse:6.34181
# [512]	validation-rmse:6.34177
# [513]	validation-rmse:6.34168
# [514]	validation-rmse:6.34154
# [515]	validation-rmse:6.34130
# [516]	validation-rmse:6.34123
# [517]	validation-rmse:6.34110
# [518]	validation-rmse:6.34093
# [519]	validation-rmse:6.34079
# [520]	validation-rmse:6.34052
# [521]	validation-rmse:6.34045
# [522]	validation-rmse:6.34033
# [523]	validation-rmse:6.34003
# [524]	validation-rmse:6.33996
# [525]	validation-rmse:6.33977
# [526]	validation-rmse:6.33969
# [527]	validation-rmse:6.33948
# [528]	validation-rmse:6.33932
# [529]	validation-rmse:6.33913
# [530]	validation-rmse:6.33890
# [531]	validation-rmse:6.33879
# [532]	validation-rmse:6.33869
# [533]	validation-rmse:6.33859
# [534]	validation-rmse:6.33841
# [535]	validation-rmse:6.33821
# [536]	validation-rmse:6.33825
# [537]	validation-rmse:6.33813
# [538]	validation-rmse:6.33807
# [539]	validation-rmse:6.33786
# [540]	validation-rmse:6.33770
# [541]	validation-rmse:6.33759
# [542]	validation-rmse:6.33734
# [543]	validation-rmse:6.33722
# [544]	validation-rmse:6.33705
# [545]	validation-rmse:6.33693
# [546]	validation-rmse:6.33692
# [547]	validation-rmse:6.33673
# [548]	validation-rmse:6.33664
# [549]	validation-rmse:6.33674
# [550]	validation-rmse:6.33657
# [551]	validation-rmse:6.33638
# [552]	validation-rmse:6.33626
# [553]	validation-rmse:6.33601
# [554]	validation-rmse:6.33603
# [555]	validation-rmse:6.33590
# [556]	validation-rmse:6.33570
# [557]	validation-rmse:6.33575
# [558]	validation-rmse:6.33562
# [559]	validation-rmse:6.33544
# [560]	validation-rmse:6.33541
# [561]	validation-rmse:6.33536
# [562]	validation-rmse:6.33521
# [563]	validation-rmse:6.33495
# [564]	validation-rmse:6.33483
# [565]	validation-rmse:6.33465
# [566]	validation-rmse:6.33451
# [567]	validation-rmse:6.33442
# [568]	validation-rmse:6.33436
# [569]	validation-rmse:6.33431
# [570]	validation-rmse:6.33419
# [571]	validation-rmse:6.33422
# [572]	validation-rmse:6.33411
# [573]	validation-rmse:6.33407
# [574]	validation-rmse:6.33394
# [575]	validation-rmse:6.33374
# [576]	validation-rmse:6.33359
# [577]	validation-rmse:6.33329
# [578]	validation-rmse:6.33320
# [579]	validation-rmse:6.33304
# [580]	validation-rmse:6.33287
# [581]	validation-rmse:6.33280
# [582]	validation-rmse:6.33240
# [583]	validation-rmse:6.33242
# [584]	validation-rmse:6.33235
# [585]	validation-rmse:6.33232
# [586]	validation-rmse:6.33220
# [587]	validation-rmse:6.33202
# [588]	validation-rmse:6.33192
# [589]	validation-rmse:6.33183
# [590]	validation-rmse:6.33166
# [591]	validation-rmse:6.33174
# [592]	validation-rmse:6.33153
# [593]	validation-rmse:6.33160
# [594]	validation-rmse:6.33148
# [595]	validation-rmse:6.33147
# [596]	validation-rmse:6.33145
# [597]	validation-rmse:6.33132
# [598]	validation-rmse:6.33128
# [599]	validation-rmse:6.33104
# [600]	validation-rmse:6.33115
# [601]	validation-rmse:6.33122
# [602]	validation-rmse:6.33117
# [603]	validation-rmse:6.33105
# [604]	validation-rmse:6.33100
# [605]	validation-rmse:6.33093
# [606]	validation-rmse:6.33082
# [607]	validation-rmse:6.33082
# [608]	validation-rmse:6.33075
# [609]	validation-rmse:6.33068
# [610]	validation-rmse:6.33057
# [611]	validation-rmse:6.33038
# [612]	validation-rmse:6.33029
# [613]	validation-rmse:6.33012
# [614]	validation-rmse:6.33011
# [615]	validation-rmse:6.33001
# [616]	validation-rmse:6.32986
# [617]	validation-rmse:6.32976
# [618]	validation-rmse:6.32965
# [619]	validation-rmse:6.32965
# [620]	validation-rmse:6.32952
# [621]	validation-rmse:6.32943
# [622]	validation-rmse:6.32932
# [623]	validation-rmse:6.32923
# [624]	validation-rmse:6.32889
# [625]	validation-rmse:6.32852
# [626]	validation-rmse:6.32858
# [627]	validation-rmse:6.32849
# [628]	validation-rmse:6.32841
# [629]	validation-rmse:6.32825
# [630]	validation-rmse:6.32818
# [631]	validation-rmse:6.32808
# [632]	validation-rmse:6.32809
# [633]	validation-rmse:6.32790
# [634]	validation-rmse:6.32790
# [635]	validation-rmse:6.32781
# [636]	validation-rmse:6.32755
# [637]	validation-rmse:6.32747
# [638]	validation-rmse:6.32735
# [639]	validation-rmse:6.32734
# [640]	validation-rmse:6.32711
# [641]	validation-rmse:6.32696
# [642]	validation-rmse:6.32686
# [643]	validation-rmse:6.32669
# [644]	validation-rmse:6.32664
# [645]	validation-rmse:6.32643
# [646]	validation-rmse:6.32617
# [647]	validation-rmse:6.32625
# [648]	validation-rmse:6.32621
# [649]	validation-rmse:6.32601
# [650]	validation-rmse:6.32597
# [651]	validation-rmse:6.32586
# [652]	validation-rmse:6.32578
# [653]	validation-rmse:6.32561
# [654]	validation-rmse:6.32554
# [655]	validation-rmse:6.32555
# [656]	validation-rmse:6.32537
# [657]	validation-rmse:6.32519
# [658]	validation-rmse:6.32508
# [659]	validation-rmse:6.32485
# [660]	validation-rmse:6.32487
# [661]	validation-rmse:6.32478
# [662]	validation-rmse:6.32463
# [663]	validation-rmse:6.32450
# [664]	validation-rmse:6.32440
# [665]	validation-rmse:6.32436
# [666]	validation-rmse:6.32442
# [667]	validation-rmse:6.32440
# [668]	validation-rmse:6.32441
# [669]	validation-rmse:6.32445
# [670]	validation-rmse:6.32435
# [671]	validation-rmse:6.32415
# [672]	validation-rmse:6.32404
# [673]	validation-rmse:6.32392
# [674]	validation-rmse:6.32374
# [675]	validation-rmse:6.32347
# [676]	validation-rmse:6.32340
# [677]	validation-rmse:6.32345
# [678]	validation-rmse:6.32335
# [679]	validation-rmse:6.32325
# [680]	validation-rmse:6.32319
# [681]	validation-rmse:6.32324
# [682]	validation-rmse:6.32306
# [683]	validation-rmse:6.32291
# [684]	validation-rmse:6.32293
# [685]	validation-rmse:6.32272
# [686]	validation-rmse:6.32264
# [687]	validation-rmse:6.32265
# [688]	validation-rmse:6.32257
# [689]	validation-rmse:6.32253
# [690]	validation-rmse:6.32241
# [691]	validation-rmse:6.32228
# [692]	validation-rmse:6.32210
# [693]	validation-rmse:6.32193
# [694]	validation-rmse:6.32184
# [695]	validation-rmse:6.32176
# [696]	validation-rmse:6.32156
# [697]	validation-rmse:6.32147
# [698]	validation-rmse:6.32141
# [699]	validation-rmse:6.32134
# [700]	validation-rmse:6.32123
# [701]	validation-rmse:6.32116
# [702]	validation-rmse:6.32102
# [703]	validation-rmse:6.32092
# [704]	validation-rmse:6.32076
# [705]	validation-rmse:6.32057
# [706]	validation-rmse:6.32052
# [707]	validation-rmse:6.32055
# [708]	validation-rmse:6.32041
# [709]	validation-rmse:6.32037
# [710]	validation-rmse:6.32036
# [711]	validation-rmse:6.32014
# [712]	validation-rmse:6.32004
# [713]	validation-rmse:6.31986
# [714]	validation-rmse:6.31975
# [715]	validation-rmse:6.31961
# [716]	validation-rmse:6.31958
# [717]	validation-rmse:6.31963
# [718]	validation-rmse:6.31961
# [719]	validation-rmse:6.31968
# [720]	validation-rmse:6.31959
# [721]	validation-rmse:6.31950
# [722]	validation-rmse:6.31917
# [723]	validation-rmse:6.31914
# [724]	validation-rmse:6.31899
# [725]	validation-rmse:6.31907
# [726]	validation-rmse:6.31905
# [727]	validation-rmse:6.31910
# [728]	validation-rmse:6.31889
# [729]	validation-rmse:6.31873
# [730]	validation-rmse:6.31869
# [731]	validation-rmse:6.31879
# [732]	validation-rmse:6.31864
# [733]	validation-rmse:6.31856
# [734]	validation-rmse:6.31850
# [735]	validation-rmse:6.31831
# [736]	validation-rmse:6.31820
# [737]	validation-rmse:6.31809
# [738]	validation-rmse:6.31802
# [739]	validation-rmse:6.31767
# [740]	validation-rmse:6.31761
# [741]	validation-rmse:6.31756
# [742]	validation-rmse:6.31765
# [743]	validation-rmse:6.31757
# [744]	validation-rmse:6.31749
# [745]	validation-rmse:6.31734
# [746]	validation-rmse:6.31727
# [747]	validation-rmse:6.31730
# [748]	validation-rmse:6.31729
# [749]	validation-rmse:6.31717
# [750]	validation-rmse:6.31705
# [751]	validation-rmse:6.31687
# [752]	validation-rmse:6.31680
# [753]	validation-rmse:6.31671
# [754]	validation-rmse:6.31651
# [755]	validation-rmse:6.31636
# [756]	validation-rmse:6.31626
# [757]	validation-rmse:6.31622
# [758]	validation-rmse:6.31613
# [759]	validation-rmse:6.31598
# [760]	validation-rmse:6.31588
# [761]	validation-rmse:6.31584
# [762]	validation-rmse:6.31571
# [763]	validation-rmse:6.31568
# [764]	validation-rmse:6.31559
# [765]	validation-rmse:6.31561
# [766]	validation-rmse:6.31549
# [767]	validation-rmse:6.31548
# [768]	validation-rmse:6.31542
# [769]	validation-rmse:6.31545
# [770]	validation-rmse:6.31545
# [771]	validation-rmse:6.31538
# [772]	validation-rmse:6.31526
# [773]	validation-rmse:6.31489
# [774]	validation-rmse:6.31492
# [775]	validation-rmse:6.31485
# [776]	validation-rmse:6.31481
# [777]	validation-rmse:6.31464
# [778]	validation-rmse:6.31479
# [779]	validation-rmse:6.31461
# [780]	validation-rmse:6.31455
# [781]	validation-rmse:6.31459
# [782]	validation-rmse:6.31467
# [783]	validation-rmse:6.31465
# [784]	validation-rmse:6.31469
# [785]	validation-rmse:6.31456
# [786]	validation-rmse:6.31451
# [787]	validation-rmse:6.31437
# [788]	validation-rmse:6.31420
# [789]	validation-rmse:6.31386
# [790]	validation-rmse:6.31372
# [791]	validation-rmse:6.31372
# [792]	validation-rmse:6.31365
# [793]	validation-rmse:6.31352
# [794]	validation-rmse:6.31354
# [795]	validation-rmse:6.31342
# [796]	validation-rmse:6.31336
# [797]	validation-rmse:6.31321
# [798]	validation-rmse:6.31311
# [799]	validation-rmse:6.31302
# [800]	validation-rmse:6.31293
# [801]	validation-rmse:6.31299
# [802]	validation-rmse:6.31303
# [803]	validation-rmse:6.31297
# [804]	validation-rmse:6.31294
# [805]	validation-rmse:6.31288
# [806]	validation-rmse:6.31261
# [807]	validation-rmse:6.31263
# [808]	validation-rmse:6.31253
# [809]	validation-rmse:6.31250
# [810]	validation-rmse:6.31244
# [811]	validation-rmse:6.31243
# [812]	validation-rmse:6.31237
# [813]	validation-rmse:6.31236
# [814]	validation-rmse:6.31236
# [815]	validation-rmse:6.31228
# [816]	validation-rmse:6.31221
# [817]	validation-rmse:6.31220
# [818]	validation-rmse:6.31219
# [819]	validation-rmse:6.31204
# [820]	validation-rmse:6.31206
# [821]	validation-rmse:6.31206
# [822]	validation-rmse:6.31200
# [823]	validation-rmse:6.31205
# [824]	validation-rmse:6.31194
# [825]	validation-rmse:6.31188
# [826]	validation-rmse:6.31180
# [827]	validation-rmse:6.31174
# [828]	validation-rmse:6.31150
# [829]	validation-rmse:6.31147
# [830]	validation-rmse:6.31113
# [831]	validation-rmse:6.31115
# [832]	validation-rmse:6.31116
# [833]	validation-rmse:6.31122
# [834]	validation-rmse:6.31111
# [835]	validation-rmse:6.31107
# [836]	validation-rmse:6.31105
# [837]	validation-rmse:6.31100
# [838]	validation-rmse:6.31083
# [839]	validation-rmse:6.31074
# [840]	validation-rmse:6.31056
# [841]	validation-rmse:6.31045
# [842]	validation-rmse:6.31045
# [843]	validation-rmse:6.31039
# [844]	validation-rmse:6.31026
# [845]	validation-rmse:6.31024
# [846]	validation-rmse:6.31018
# [847]	validation-rmse:6.31003
# [848]	validation-rmse:6.30992
# [849]	validation-rmse:6.30993
# [850]	validation-rmse:6.30999
# [851]	validation-rmse:6.30970
# [852]	validation-rmse:6.30967
# [853]	validation-rmse:6.30965
# [854]	validation-rmse:6.30968
# [855]	validation-rmse:6.30956
# [856]	validation-rmse:6.30950
# [857]	validation-rmse:6.30945
# [858]	validation-rmse:6.30921
# [859]	validation-rmse:6.30899
# [860]	validation-rmse:6.30896
# [861]	validation-rmse:6.30851
# [862]	validation-rmse:6.30869
# [863]	validation-rmse:6.30865
# [864]	validation-rmse:6.30872
# [865]	validation-rmse:6.30859
# [866]	validation-rmse:6.30844
# [867]	validation-rmse:6.30827
# [868]	validation-rmse:6.30827
# [869]	validation-rmse:6.30818
# [870]	validation-rmse:6.30809
# [871]	validation-rmse:6.30807
# [872]	validation-rmse:6.30811
# [873]	validation-rmse:6.30817
# [874]	validation-rmse:6.30814
# [875]	validation-rmse:6.30798
# [876]	validation-rmse:6.30792
# [877]	validation-rmse:6.30785
# [878]	validation-rmse:6.30773
# [879]	validation-rmse:6.30784
# [880]	validation-rmse:6.30790
# [881]	validation-rmse:6.30789
# [882]	validation-rmse:6.30778
# [883]	validation-rmse:6.30789
# [884]	validation-rmse:6.30779
# [885]	validation-rmse:6.30777
# [886]	validation-rmse:6.30772
# [887]	validation-rmse:6.30758
# [888]	validation-rmse:6.30754
# [889]	validation-rmse:6.30737
# [890]	validation-rmse:6.30741
# [891]	validation-rmse:6.30745
# [892]	validation-rmse:6.30749
# [893]	validation-rmse:6.30769
# [894]	validation-rmse:6.30777
# [895]	validation-rmse:6.30777
# [896]	validation-rmse:6.30762
# [897]	validation-rmse:6.30752
# [898]	validation-rmse:6.30746
# [899]	validation-rmse:6.30749
# [900]	validation-rmse:6.30745
# [901]	validation-rmse:6.30734
# [902]	validation-rmse:6.30720
# [903]	validation-rmse:6.30716
# [904]	validation-rmse:6.30706
# [905]	validation-rmse:6.30705
# [906]	validation-rmse:6.30700
# [907]	validation-rmse:6.30686
# [908]	validation-rmse:6.30688
# [909]	validation-rmse:6.30670
# [910]	validation-rmse:6.30666
# [911]	validation-rmse:6.30645
# [912]	validation-rmse:6.30651
# [913]	validation-rmse:6.30654
# [914]	validation-rmse:6.30660
# [915]	validation-rmse:6.30648
# [916]	validation-rmse:6.30646
# [917]	validation-rmse:6.30640
# [918]	validation-rmse:6.30632
# [919]	validation-rmse:6.30632
# [920]	validation-rmse:6.30630
# [921]	validation-rmse:6.30620
# [922]	validation-rmse:6.30584
# [923]	validation-rmse:6.30592
# [924]	validation-rmse:6.30593
# [925]	validation-rmse:6.30597
# [926]	validation-rmse:6.30587
# [927]	validation-rmse:6.30579
# [928]	validation-rmse:6.30576
# [929]	validation-rmse:6.30570
# [930]	validation-rmse:6.30565
# [931]	validation-rmse:6.30562
# [932]	validation-rmse:6.30551
# [933]	validation-rmse:6.30539
# [934]	validation-rmse:6.30542
# [935]	validation-rmse:6.30543
# [936]	validation-rmse:6.30547
# [937]	validation-rmse:6.30549
# [938]	validation-rmse:6.30548
# [939]	validation-rmse:6.30548
# [940]	validation-rmse:6.30536
# [941]	validation-rmse:6.30525
# [942]	validation-rmse:6.30521
# [943]	validation-rmse:6.30512
# [944]	validation-rmse:6.30521
# [945]	validation-rmse:6.30523
# [946]	validation-rmse:6.30517
# [947]	validation-rmse:6.30511
# [948]	validation-rmse:6.30510
# [949]	validation-rmse:6.30512
# [950]	validation-rmse:6.30509
# [951]	validation-rmse:6.30506
# [952]	validation-rmse:6.30489
# [953]	validation-rmse:6.30465
# [954]	validation-rmse:6.30443
# [955]	validation-rmse:6.30442
# [956]	validation-rmse:6.30449
# [957]	validation-rmse:6.30447
# [958]	validation-rmse:6.30450
# [959]	validation-rmse:6.30443
# [960]	validation-rmse:6.30436
# [961]	validation-rmse:6.30432
# [962]	validation-rmse:6.30435
# [963]	validation-rmse:6.30428
# [964]	validation-rmse:6.30422
# [965]	validation-rmse:6.30423
# [966]	validation-rmse:6.30420
# [967]	validation-rmse:6.30423
# [968]	validation-rmse:6.30425
# [969]	validation-rmse:6.30427
# [970]	validation-rmse:6.30418
# [971]	validation-rmse:6.30425
# [972]	validation-rmse:6.30403
# [973]	validation-rmse:6.30398
# [974]	validation-rmse:6.30395
# [975]	validation-rmse:6.30398
# [976]	validation-rmse:6.30405
# [977]	validation-rmse:6.30393
# [978]	validation-rmse:6.30390
# [979]	validation-rmse:6.30365
# [980]	validation-rmse:6.30378
# [981]	validation-rmse:6.30369
# [982]	validation-rmse:6.30358
# [983]	validation-rmse:6.30352
# [984]	validation-rmse:6.30356
# [985]	validation-rmse:6.30358
# [986]	validation-rmse:6.30348
# [987]	validation-rmse:6.30374
# [988]	validation-rmse:6.30333
# [989]	validation-rmse:6.30327
# [990]	validation-rmse:6.30324
# [991]	validation-rmse:6.30323
# [992]	validation-rmse:6.30314
# [993]	validation-rmse:6.30309
# [994]	validation-rmse:6.30303
# [995]	validation-rmse:6.30293
# [996]	validation-rmse:6.30280
# [997]	validation-rmse:6.30273
# [998]	validation-rmse:6.30259
# [999]	validation-rmse:6.30243

# %%
logged_model = 'runs:/7a912515768f48ac8ec14a1e2e6450eb/model'

# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(logged_model)
# Out:
# [17:10:12] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-0fc7796c793e6356f-1/xgboost/xgboost-ci-windows/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.

# %%
loaded_model
# Out:
# mlflow.pyfunc.loaded_model:
#   artifact_path: model
#   flavor: mlflow.xgboost
#   run_id: 7a912515768f48ac8ec14a1e2e6450eb

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from sklearn.svm import LinearSVR

mlflow.sklearn.autolog()

for model_class in (RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor, LinearSVR):

    with mlflow.start_run():

        mlflow.log_param("train-data-path", "./data/green_tripdata_2021-01.csv")
        mlflow.log_param("valid-data-path", "./data/green_tripdata_2021-02.csv")
        mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")

        mlmodel = model_class()
        mlmodel.fit(X_train, y_train)

        y_pred = mlmodel.predict(X_val)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)
# Out:
# c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
